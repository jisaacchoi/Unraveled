# %%
import gzip
import json
from pathlib import Path

# Update this path
file_path = "D:\\payer_mrf_2\\workspace\\group_850546fc2259"
file_path = f"{file_path}\\2026-01_890_58B0_in-network-rates_02_of_60_part0001.json.gz"

with gzip.open(file_path, "rt", encoding="utf-8") as f:
    data = json.load(f)

# in_network = data.get("in_network", [])
# print("file:", file_path)
# print("len(in_network):", len(in_network))

# %%
in_network=data.get("in_network", [])
in_network[1]
# Out:
# {'billing_code_type': 'CPT',
#  'billing_code': '64600',
#  'billing_code_type_version': '2025',
#  'description': 'DESTRUCTION BY NEUROLYTIC AGENT, TRIGEMINAL NERVE; SUPRAORBITAL, INFRAORBITAL, MENTAL, OR INFERIOR ALVEOLAR BRANCH',
#  'name': 'DESTRUCTION BY NEUROLYTIC AGENT, TRIGEMINAL NERVE; SUPRAORBITAL, INFRAORBITAL, MENTAL, OR INFERIOR ALVEOLAR BRANCH',
#  'negotiated_rates': [{'negotiated_prices': [{'billing_class': 'professional',
#      'billing_code_modifier': [],
#      'expiration_date': '9999-12-31',
#      'negotiated_rate': 282.88,
#      'negotiated_type': 'negotiated',
#      'service_code': ['01',
#       '03',
#       '04',
#       '05',
#       '07',
#       '09',
#       '11',
#       '12',
#       '14',
#       '15',
#       '20',
#       '34',
#       '41',
#       '42',
#       '49',
#       '50',
#       '53',
#       '57',
#       '60',
#       '65',
#       '71',
#       '72',
#       '81',
#       '99',
#       '02',
#       '19',
#       '10',
# ...

# %%
import gzip
import json
from pathlib import Path

# Update this path
file_paths=list()
file_path = "D:\\payer_mrf_2\\workspace\\group_e2a4f730934b"
file_paths.append(f"{file_path}\\2026-01_320_33B0_in-network-rates_01_of_10_part0001.json.gz")
file_paths.append(f"{file_path}\\2026-01_320_33B0_in-network-rates_01_of_10_part0002.json.gz")
file_paths.append(f"{file_path}\\2026-01_320_33B0_in-network-rates_01_of_10_part0003.json.gz")
file_paths.append(f"{file_path}\\2026-01_320_33B0_in-network-rates_01_of_10_part0004.json.gz")
file_paths.append(f"{file_path}\\2026-01_320_33B0_in-network-rates_01_of_10_part0005.json.gz")
file_paths.append(f"{file_path}\\2026-01_320_33B0_in-network-rates_01_of_10_part0006.json.gz")
file_paths.append(f"{file_path}\\2026-01_320_33B0_in-network-rates_01_of_10_part0007.json.gz")
file_paths.append(f"{file_path}\\2026-01_320_33B0_in-network-rates_01_of_10_part0008.json.gz")
file_paths.append(f"{file_path}\\2026-01_320_33B0_in-network-rates_01_of_10_part0009.json.gz")
file_paths.append(f"{file_path}\\2026-01_320_33B0_in-network-rates_01_of_10_part0010.json.gz")

total_len=0
for fp in file_paths:
    with gzip.open(fp, "rt", encoding="utf-8") as f:
        data = json.load(f)

    in_network = data.get("in_network", [])
    total_len+=len(in_network)
    print(fp)
    
print("file:", file_path)
print("len(in_network):", total_len)
# Out:
# D:\payer_mrf_2\workspace\group_e2a4f730934b\2026-01_320_33B0_in-network-rates_01_of_10_part0001.json.gz
# D:\payer_mrf_2\workspace\group_e2a4f730934b\2026-01_320_33B0_in-network-rates_01_of_10_part0002.json.gz
# D:\payer_mrf_2\workspace\group_e2a4f730934b\2026-01_320_33B0_in-network-rates_01_of_10_part0003.json.gz
# D:\payer_mrf_2\workspace\group_e2a4f730934b\2026-01_320_33B0_in-network-rates_01_of_10_part0004.json.gz
# D:\payer_mrf_2\workspace\group_e2a4f730934b\2026-01_320_33B0_in-network-rates_01_of_10_part0005.json.gz
# D:\payer_mrf_2\workspace\group_e2a4f730934b\2026-01_320_33B0_in-network-rates_01_of_10_part0006.json.gz
# D:\payer_mrf_2\workspace\group_e2a4f730934b\2026-01_320_33B0_in-network-rates_01_of_10_part0007.json.gz
# D:\payer_mrf_2\workspace\group_e2a4f730934b\2026-01_320_33B0_in-network-rates_01_of_10_part0008.json.gz
# D:\payer_mrf_2\workspace\group_e2a4f730934b\2026-01_320_33B0_in-network-rates_01_of_10_part0009.json.gz
# ...
