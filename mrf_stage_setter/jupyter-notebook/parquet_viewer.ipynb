# %%
#!/usr/bin/env python3
"""
Read Parquet files using pandas (for local/regular Python environments).

Usage:
    python scripts/read_parquet_pandas.py
"""
from pathlib import Path
import pandas as pd

# Path to the Parquet directory (contains part-*.parquet files)
parquet_path = "C:\\Users\\ichoi\\Downloads\\in_network_rates.parquet (20)\\in_network_rates.parquet\\npi_partition=0\\part-00006-tid-989942598934054284-1ed134e7-ea35-4331-9c2f-a47e40d8e58f-1482-1.c000.zstd.parquet"
print(f"Reading Parquet files from: {parquet_path}")

# Read all Parquet files in the directory
df = pd.read_parquet(parquet_path)

print(f"\\nDataFrame shape: {df.shape}")
print(f"Columns: {list(df.columns)}")
print(f"\\nFirst few rows:")
print(df.head())

print(f"\\nData types:")
print
# Out:
# Reading Parquet files from: C:\Users\ichoi\Downloads\in_network_rates.parquet (20)\in_network_rates.parquet\npi_partition=0\part-00006-tid-989942598934054284-1ed134e7-ea35-4331-9c2f-a47e40d8e58f-1482-1.c000.zstd.parquet
# \nDataFrame shape: (446326, 19)
# Columns: ['provider_group_id', 'source_file', 'billing_code', 'billing_code_type', 'billing_code_type_version', 'description', 'name', 'negotiation_arrangement', 'billing_class', 'expiration_date', 'negotiated_rate', 'negotiated_type', 'service_code', 'npi', 'reporting_entity_name', 'plan_id', 'plan_name', 'plan_id_type', 'plan_market_type']
# \nFirst few rows:
#   provider_group_id                                source_file billing_code  \
# 0         250.10285  2025-12_250_31B0_in-network-rates.json.gz        78832
# 1         250.10285  2025-12_250_31B0_in-network-rates.json.gz        78832
# 2         250.10367  2025-12_250_31B0_in-network-rates.json.gz        76886
# ...

# %%
df.columns
# Out:
# Index(['provider_group_id', 'source_file', 'billing_code', 'billing_code_type',
#        'billing_code_type_version', 'description', 'name',
#        'negotiation_arrangement', 'billing_class', 'expiration_date',
#        'negotiated_rate', 'negotiated_type', 'service_code', 'npi',
#        'reporting_entity_name', 'plan_id', 'plan_name', 'plan_id_type',
#        'plan_market_type'],
#       dtype='object')
