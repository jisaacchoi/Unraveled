# %% [markdown]
# # Random-access `.json.gz` scanning with igzip index + chunked key counting
#
# This notebook does **two** things on a large `json.gz`:
#
# 1. Builds an **indexed gzip** (igzip) random-access index so you can later seek to decompressed offsets efficiently.
# 2. Streams the **decompressed** JSON text in chunks, uses a regex to extract **JSON object keys** (`"key":`), maintains **running counts**, and records **byte offsets** (in the decompressed stream) for each key occurrence.
#
# Design notes:
# - The scan is performed on the **decompressed** byte stream (the same address space the igzip index typically targets).
# - To handle keys split across chunk boundaries, the scanner keeps a small **tail overlap** (default 2 KB) and counts any regex match whose **end** crosses into the new chunk.
# - Offsets are recorded as:
#   - `abs_offset`: decompressed byte offset from the start of the JSON text
#   - `chunk_index`: `abs_offset // chunk_size`
#   - `offset_in_chunk`: `abs_offset % chunk_size`

# %%
# --- Dependencies ---
# The most common Python package providing "igzip-like" random access is `indexed_gzip`.
# If it's not installed in your environment, uncomment and run the pip install cell.

# !pip -q install indexed_gzip

import re
import json
from collections import Counter, defaultdict
from dataclasses import dataclass
from pathlib import Path
from typing import Dict, Iterable, List, Tuple, Optional
import indexed_gzip
import os, time

# %%
# --- Open an indexed gzip file (igzip) ---
# `indexed_gzip` provides an IndexedGzipFile that can build and export an index.

def open_indexed_gzip(gz_path: str):
    # `drop_handles=False` helps keep handles for faster access in some environments.
    f = indexed_gzip.IndexedGzipFile(gz_path)
    return f

# %%
# --- Build + export igzip index ---

def build_and_export_index(gz_path: str, index_path: str):
    """Build a full index and export it to a file.

    Notes:
      - Building a full index can take time on huge files, but enables fast seeking later.
      - Index format is specific to `indexed_gzip`.
    """
    f = open_indexed_gzip(gz_path)
    # Build full index over the compressed file
    f.build_full_index()
    # Export index to disk
    index_path = str(index_path)
    f.export_index(index_path)
    f.close()
    return index_path


def open_with_existing_index(gz_path: str, index_path: str):
    """Open an indexed gzip using a pre-built exported index."""
    import indexed_gzip
    f = indexed_gzip.IndexedGzipFile(gz_path)
    f.import_index(index_path)
    return f

# %% [markdown]
# ## Chunked regex scan for JSON keys
#
# We treat the gzip stream as UTF-8 JSON text.
#
# Regex:
# - We look for JSON object keys: `"<string>":`
# - Pattern is tolerant of escaped quotes inside strings.
#
# Boundary handling:
# - Keep a **tail overlap** (`overlap_bytes`, default 2048).
# - For each chunk, scan `tail + chunk`.
# - Count any match whose **end position** is **after** the tail length; this guarantees we count boundary-spanning keys exactly once.
#
# Offset attribution:
# - `abs_offset` is computed as `chunk_start_abs - len(tail) + match.start()`
#   - `chunk_start_abs` is the decompressed offset where the current chunk begins.

# %%
# --- Scanner implementation ---

KEY_PATTERN = re.compile(rb'"((?:\\.|[^"\\]){1,512})"\s*:')

@dataclass
class KeyHit:
    key: str
    abs_offset: int          # decompressed absolute byte offset
    chunk_index: int
    offset_in_chunk: int


def _decode_json_string_bytes(b: bytes) -> str:
    s = b.decode("utf-8", errors="replace")
    try:
        return json.loads('"' + s.replace('"', '\\"') + '"')
    except Exception:
        return s


def scan_unique_keys_with_offsets(
    gz_path: str,
    index_path: str | None = None,
    chunk_size: int = 8 * 1024 * 1024,
    overlap_bytes: int = 2048,
    progress_every_chunks: int = 20,
):

    total_compressed = os.path.getsize(gz_path)
    start_time = time.time()

    if index_path:
        f = open_with_existing_index(gz_path, index_path)
    else:
        f = open_indexed_gzip(gz_path)

    seen_once: dict[str, int] = {}
    seen_multiple: set[str] = set()

    tail = b""
    abs_read = 0
    chunk_index = 0

    while True:
        chunk = f.read(chunk_size)
        if not chunk:
            break

        chunk_start_abs = abs_read
        abs_read += len(chunk)

        combined = tail + chunk
        tail_len = len(tail)

        for m in KEY_PATTERN.finditer(combined):
            if m.end() <= tail_len:
                continue

            key = _decode_json_string_bytes(m.group(1))
            abs_offset = chunk_start_abs - tail_len + m.start()
            if abs_offset < 0:
                abs_offset = m.start()

            if key in seen_multiple:
                continue

            if key in seen_once:
                del seen_once[key]
                seen_multiple.add(key)
            else:
                seen_once[key] = abs_offset

        tail = combined[-overlap_bytes:] if overlap_bytes > 0 else b""
        chunk_index += 1

        if progress_every_chunks and (chunk_index % progress_every_chunks == 0):
            elapsed = time.time() - start_time
            msg = (
                f"Scanned {chunk_index:,} chunks | "
                f"{abs_read:,} decompressed bytes | "
            )

            # --- compressed % progress ---
            try:
                compressed_pos = f.fileobj().tell()
                pct = 100.0 * compressed_pos / total_compressed
                msg += f"{pct:6.2f}% compressed | "
            except Exception:
                msg += "compressed % unavailable | "

            msg += f"{elapsed:,.1f}s elapsed"
            print(msg)

    f.close()

    unique_hits = {
        k: KeyHit(
            key=k,
            abs_offset=o,
            chunk_index=o // chunk_size,
            offset_in_chunk=o % chunk_size,
        )
        for k, o in seen_once.items()
    }

    return unique_hits

# %%
# # --- Example usage ---

# # 1) Set paths
gz_path = "D:\\2026-01_254_39D0_in-network-rates_4_of_5.json.gz"
index_path = f"{gz_path}.gzi"

# 2) Build index (optional if already built)
build_and_export_index(gz_path, index_path)

# 3) Scan keys + offsets
unique_hits = scan_unique_keys_with_offsets(
    gz_path=gz_path,
    index_path=index_path,
    chunk_size=8*1024*1024,
    overlap_bytes=2048,
)

len(unique_hits), list(unique_hits.items())
# Out:
# Scanned 20 chunks, 167,772,160 decompressed bytes...
# Scanned 40 chunks, 335,544,320 decompressed bytes...
# Scanned 60 chunks, 503,316,480 decompressed bytes...
# Scanned 80 chunks, 671,088,640 decompressed bytes...
# Scanned 100 chunks, 838,860,800 decompressed bytes...
# Scanned 120 chunks, 1,006,632,960 decompressed bytes...
# Scanned 140 chunks, 1,174,405,120 decompressed bytes...
# Scanned 160 chunks, 1,342,177,280 decompressed bytes...
# Scanned 180 chunks, 1,509,949,440 decompressed bytes...
# Scanned 200 chunks, 1,677,721,600 decompressed bytes...
# Scanned 220 chunks, 1,845,493,760 decompressed bytes...
# Scanned 240 chunks, 2,013,265,920 decompressed bytes...
# Scanned 260 chunks, 2,181,038,080 decompressed bytes...
# Scanned 280 chunks, 2,348,810,240 decompressed bytes...
# Scanned 300 chunks, 2,516,582,400 decompressed bytes...
# Scanned 320 chunks, 2,684,354,560 decompressed bytes...
# Scanned 340 chunks, 2,852,126,720 decompressed bytes...
# Scanned 360 chunks, 3,019,898,880 decompressed bytes...
# Scanned 380 chunks, 3,187,671,040 decompressed bytes...
# Scanned 400 chunks, 3,355,443,200 decompressed bytes...
# Scanned 420 chunks, 3,523,215,360 decompressed bytes...
# Scanned 440 chunks, 3,690,987,520 decompressed bytes...
# Scanned 460 chunks, 3,858,759,680 decompressed bytes...
# Scanned 480 chunks, 4,026,531,840 decompressed bytes...
# Scanned 500 chunks, 4,194,304,000 decompressed bytes...
# Scanned 520 chunks, 4,362,076,160 decompressed bytes...
# Scanned 540 chunks, 4,529,848,320 decompressed bytes...
# Scanned 560 chunks, 4,697,620,480 decompressed bytes...
# Scanned 580 chunks, 4,865,392,640 decompressed bytes...
# Scanned 600 chunks, 5,033,164,800 decompressed bytes...
# Scanned 620 chunks, 5,200,936,960 decompressed bytes...
# Scanned 640 chunks, 5,368,709,120 decompressed bytes...
# Scanned 660 chunks, 5,536,481,280 decompressed bytes...
# Scanned 680 chunks, 5,704,253,440 decompressed bytes...
# Scanned 700 chunks, 5,872,025,600 decompressed bytes...
# Scanned 720 chunks, 6,039,797,760 decompressed bytes...
# Scanned 740 chunks, 6,207,569,920 decompressed bytes...
# Scanned 760 chunks, 6,375,342,080 decompressed bytes...
# Scanned 780 chunks, 6,543,114,240 decompressed bytes...
# Scanned 800 chunks, 6,710,886,400 decompressed bytes...
# Scanned 820 chunks, 6,878,658,560 decompressed bytes...
# Scanned 840 chunks, 7,046,430,720 decompressed bytes...
# Scanned 860 chunks, 7,214,202,880 decompressed bytes...
# Scanned 880 chunks, 7,381,975,040 decompressed bytes...
# Scanned 900 chunks, 7,549,747,200 decompressed bytes...
# Scanned 920 chunks, 7,717,519,360 decompressed bytes...
# Scanned 940 chunks, 7,885,291,520 decompressed bytes...
# Scanned 960 chunks, 8,053,063,680 decompressed bytes...
# Scanned 980 chunks, 8,220,835,840 decompressed bytes...
# Scanned 1000 chunks, 8,388,608,000 decompressed bytes...
# Scanned 1020 chunks, 8,556,380,160 decompressed bytes...
# Scanned 1040 chunks, 8,724,152,320 decompressed bytes...
# Scanned 1060 chunks, 8,891,924,480 decompressed bytes...
# Scanned 1080 chunks, 9,059,696,640 decompressed bytes...
# Scanned 1100 chunks, 9,227,468,800 decompressed bytes...
# Scanned 1120 chunks, 9,395,240,960 decompressed bytes...
# Scanned 1140 chunks, 9,563,013,120 decompressed bytes...
# Scanned 1160 chunks, 9,730,785,280 decompressed bytes...
# Scanned 1180 chunks, 9,898,557,440 decompressed bytes...
# Scanned 1200 chunks, 10,066,329,600 decompressed bytes...
# Scanned 1220 chunks, 10,234,101,760 decompressed bytes...
# Scanned 1240 chunks, 10,401,873,920 decompressed bytes...
# Scanned 1260 chunks, 10,569,646,080 decompressed bytes...
# Scanned 1280 chunks, 10,737,418,240 decompressed bytes...
# Scanned 1300 chunks, 10,905,190,400 decompressed bytes...
# Scanned 1320 chunks, 11,072,962,560 decompressed bytes...
# Scanned 1340 chunks, 11,240,734,720 decompressed bytes...
# Scanned 1360 chunks, 11,408,506,880 decompressed bytes...
# Scanned 1380 chunks, 11,576,279,040 decompressed bytes...
# Scanned 1400 chunks, 11,744,051,200 decompressed bytes...
# Scanned 1420 chunks, 11,911,823,360 decompressed bytes...
# Scanned 1440 chunks, 12,079,595,520 decompressed bytes...
# Scanned 1460 chunks, 12,247,367,680 decompressed bytes...
# Scanned 1480 chunks, 12,415,139,840 decompressed bytes...
# Scanned 1500 chunks, 12,582,912,000 decompressed bytes...
# Scanned 1520 chunks, 12,750,684,160 decompressed bytes...
# Scanned 1540 chunks, 12,918,456,320 decompressed bytes...
# Scanned 1560 chunks, 13,086,228,480 decompressed bytes...
# Scanned 1580 chunks, 13,254,000,640 decompressed bytes...
# Scanned 1600 chunks, 13,421,772,800 decompressed bytes...
# Scanned 1620 chunks, 13,589,544,960 decompressed bytes...
# Scanned 1640 chunks, 13,757,317,120 decompressed bytes...
# Scanned 1660 chunks, 13,925,089,280 decompressed bytes...
# Scanned 1680 chunks, 14,092,861,440 decompressed bytes...
# Scanned 1700 chunks, 14,260,633,600 decompressed bytes...
# Scanned 1720 chunks, 14,428,405,760 decompressed bytes...
# Scanned 1740 chunks, 14,596,177,920 decompressed bytes...
# Scanned 1760 chunks, 14,763,950,080 decompressed bytes...
# Scanned 1780 chunks, 14,931,722,240 decompressed bytes...
# Scanned 1800 chunks, 15,099,494,400 decompressed bytes...
# Scanned 1820 chunks, 15,267,266,560 decompressed bytes...
# Scanned 1840 chunks, 15,435,038,720 decompressed bytes...
# Scanned 1860 chunks, 15,602,810,880 decompressed bytes...
# Scanned 1880 chunks, 15,770,583,040 decompressed bytes...
# Scanned 1900 chunks, 15,938,355,200 decompressed bytes...
# Scanned 1920 chunks, 16,106,127,360 decompressed bytes...
# Scanned 1940 chunks, 16,273,899,520 decompressed bytes...
# Scanned 1960 chunks, 16,441,671,680 decompressed bytes...
# Scanned 1980 chunks, 16,609,443,840 decompressed bytes...
# Scanned 2000 chunks, 16,777,216,000 decompressed bytes...
# Scanned 2020 chunks, 16,944,988,160 decompressed bytes...
# Scanned 2040 chunks, 17,112,760,320 decompressed bytes...
# Scanned 2060 chunks, 17,280,532,480 decompressed bytes...
# Scanned 2080 chunks, 17,448,304,640 decompressed bytes...
# Scanned 2100 chunks, 17,616,076,800 decompressed bytes...
# Scanned 2120 chunks, 17,783,848,960 decompressed bytes...
# Scanned 2140 chunks, 17,951,621,120 decompressed bytes...
# Scanned 2160 chunks, 18,119,393,280 decompressed bytes...
# Scanned 2180 chunks, 18,287,165,440 decompressed bytes...
# Scanned 2200 chunks, 18,454,937,600 decompressed bytes...
# Scanned 2220 chunks, 18,622,709,760 decompressed bytes...
# Scanned 2240 chunks, 18,790,481,920 decompressed bytes...
# Scanned 2260 chunks, 18,958,254,080 decompressed bytes...
# Scanned 2280 chunks, 19,126,026,240 decompressed bytes...
# Scanned 2300 chunks, 19,293,798,400 decompressed bytes...
# Scanned 2320 chunks, 19,461,570,560 decompressed bytes...
# Scanned 2340 chunks, 19,629,342,720 decompressed bytes...
# Scanned 2360 chunks, 19,797,114,880 decompressed bytes...
# Scanned 2380 chunks, 19,964,887,040 decompressed bytes...
# Scanned 2400 chunks, 20,132,659,200 decompressed bytes...
# Scanned 2420 chunks, 20,300,431,360 decompressed bytes...
# Scanned 2440 chunks, 20,468,203,520 decompressed bytes...
# Scanned 2460 chunks, 20,635,975,680 decompressed bytes...
# Scanned 2480 chunks, 20,803,747,840 decompressed bytes...
# Scanned 2500 chunks, 20,971,520,000 decompressed bytes...
# Scanned 2520 chunks, 21,139,292,160 decompressed bytes...
# Scanned 2540 chunks, 21,307,064,320 decompressed bytes...
# Scanned 2560 chunks, 21,474,836,480 decompressed bytes...
# Scanned 2580 chunks, 21,642,608,640 decompressed bytes...
# Scanned 2600 chunks, 21,810,380,800 decompressed bytes...
# Scanned 2620 chunks, 21,978,152,960 decompressed bytes...
# Scanned 2640 chunks, 22,145,925,120 decompressed bytes...
# Scanned 2660 chunks, 22,313,697,280 decompressed bytes...
# Scanned 2680 chunks, 22,481,469,440 decompressed bytes...
# Scanned 2700 chunks, 22,649,241,600 decompressed bytes...
# Scanned 2720 chunks, 22,817,013,760 decompressed bytes...
# Scanned 2740 chunks, 22,984,785,920 decompressed bytes...
# Scanned 2760 chunks, 23,152,558,080 decompressed bytes...
# Scanned 2780 chunks, 23,320,330,240 decompressed bytes...
# Scanned 2800 chunks, 23,488,102,400 decompressed bytes...
# Scanned 2820 chunks, 23,655,874,560 decompressed bytes...
# Scanned 2840 chunks, 23,823,646,720 decompressed bytes...
# Scanned 2860 chunks, 23,991,418,880 decompressed bytes...
# Scanned 2880 chunks, 24,159,191,040 decompressed bytes...
# Scanned 2900 chunks, 24,326,963,200 decompressed bytes...
# Scanned 2920 chunks, 24,494,735,360 decompressed bytes...
# Scanned 2940 chunks, 24,662,507,520 decompressed bytes...
# Scanned 2960 chunks, 24,830,279,680 decompressed bytes...
# Scanned 2980 chunks, 24,998,051,840 decompressed bytes...
# Scanned 3000 chunks, 25,165,824,000 decompressed bytes...
# Scanned 3020 chunks, 25,333,596,160 decompressed bytes...
# Scanned 3040 chunks, 25,501,368,320 decompressed bytes...
# Scanned 3060 chunks, 25,669,140,480 decompressed bytes...
# Scanned 3080 chunks, 25,836,912,640 decompressed bytes...
# Scanned 3100 chunks, 26,004,684,800 decompressed bytes...
# Scanned 3120 chunks, 26,172,456,960 decompressed bytes...
# Scanned 3140 chunks, 26,340,229,120 decompressed bytes...
# Scanned 3160 chunks, 26,508,001,280 decompressed bytes...
# Scanned 3180 chunks, 26,675,773,440 decompressed bytes...
# Scanned 3200 chunks, 26,843,545,600 decompressed bytes...
# Scanned 3220 chunks, 27,011,317,760 decompressed bytes...
# Scanned 3240 chunks, 27,179,089,920 decompressed bytes...
# Scanned 3260 chunks, 27,346,862,080 decompressed bytes...
# Scanned 3280 chunks, 27,514,634,240 decompressed bytes...
# Scanned 3300 chunks, 27,682,406,400 decompressed bytes...
# Scanned 3320 chunks, 27,850,178,560 decompressed bytes...
# Scanned 3340 chunks, 28,017,950,720 decompressed bytes...
# Scanned 3360 chunks, 28,185,722,880 decompressed bytes...
# Scanned 3380 chunks, 28,353,495,040 decompressed bytes...
# Scanned 3400 chunks, 28,521,267,200 decompressed bytes...
# Scanned 3420 chunks, 28,689,039,360 decompressed bytes...
# Scanned 3440 chunks, 28,856,811,520 decompressed bytes...
# Scanned 3460 chunks, 29,024,583,680 decompressed bytes...
# Scanned 3480 chunks, 29,192,355,840 decompressed bytes...
# Scanned 3500 chunks, 29,360,128,000 decompressed bytes...
# Scanned 3520 chunks, 29,527,900,160 decompressed bytes...
# Scanned 3540 chunks, 29,695,672,320 decompressed bytes...
# Scanned 3560 chunks, 29,863,444,480 decompressed bytes...
# Scanned 3580 chunks, 30,031,216,640 decompressed bytes...
# Scanned 3600 chunks, 30,198,988,800 decompressed bytes...
# Scanned 3620 chunks, 30,366,760,960 decompressed bytes...
# Scanned 3640 chunks, 30,534,533,120 decompressed bytes...
# Scanned 3660 chunks, 30,702,305,280 decompressed bytes...
# Scanned 3680 chunks, 30,870,077,440 decompressed bytes...
# Scanned 3700 chunks, 31,037,849,600 decompressed bytes...
# Scanned 3720 chunks, 31,205,621,760 decompressed bytes...
# Scanned 3740 chunks, 31,373,393,920 decompressed bytes...
# Scanned 3760 chunks, 31,541,166,080 decompressed bytes...
# Scanned 3780 chunks, 31,708,938,240 decompressed bytes...
# Scanned 3800 chunks, 31,876,710,400 decompressed bytes...
# Scanned 3820 chunks, 32,044,482,560 decompressed bytes...
# Scanned 3840 chunks, 32,212,254,720 decompressed bytes...
# Scanned 3860 chunks, 32,380,026,880 decompressed bytes...
# Scanned 3880 chunks, 32,547,799,040 decompressed bytes...
# Scanned 3900 chunks, 32,715,571,200 decompressed bytes...
# Scanned 3920 chunks, 32,883,343,360 decompressed bytes...
# Scanned 3940 chunks, 33,051,115,520 decompressed bytes...
# Scanned 3960 chunks, 33,218,887,680 decompressed bytes...
# Scanned 3980 chunks, 33,386,659,840 decompressed bytes...
# Scanned 4000 chunks, 33,554,432,000 decompressed bytes...
# Scanned 4020 chunks, 33,722,204,160 decompressed bytes...
# Scanned 4040 chunks, 33,889,976,320 decompressed bytes...
# Scanned 4060 chunks, 34,057,748,480 decompressed bytes...
# Scanned 4080 chunks, 34,225,520,640 decompressed bytes...
# Scanned 4100 chunks, 34,393,292,800 decompressed bytes...
# Scanned 4120 chunks, 34,561,064,960 decompressed bytes...
# Scanned 4140 chunks, 34,728,837,120 decompressed bytes...
# Scanned 4160 chunks, 34,896,609,280 decompressed bytes...
# Scanned 4180 chunks, 35,064,381,440 decompressed bytes...
# Scanned 4200 chunks, 35,232,153,600 decompressed bytes...
# Scanned 4220 chunks, 35,399,925,760 decompressed bytes...
# Scanned 4240 chunks, 35,567,697,920 decompressed bytes...
# Scanned 4260 chunks, 35,735,470,080 decompressed bytes...
# Scanned 4280 chunks, 35,903,242,240 decompressed bytes...
# Scanned 4300 chunks, 36,071,014,400 decompressed bytes...
# Scanned 4320 chunks, 36,238,786,560 decompressed bytes...
# Scanned 4340 chunks, 36,406,558,720 decompressed bytes...
# Scanned 4360 chunks, 36,574,330,880 decompressed bytes...
# Scanned 4380 chunks, 36,742,103,040 decompressed bytes...
# Scanned 4400 chunks, 36,909,875,200 decompressed bytes...
# Scanned 4420 chunks, 37,077,647,360 decompressed bytes...
# Scanned 4440 chunks, 37,245,419,520 decompressed bytes...
# Scanned 4460 chunks, 37,413,191,680 decompressed bytes...
# Scanned 4480 chunks, 37,580,963,840 decompressed bytes...
# Scanned 4500 chunks, 37,748,736,000 decompressed bytes...
# Scanned 4520 chunks, 37,916,508,160 decompressed bytes...
# Scanned 4540 chunks, 38,084,280,320 decompressed bytes...
# Scanned 4560 chunks, 38,252,052,480 decompressed bytes...
# Scanned 4580 chunks, 38,419,824,640 decompressed bytes...
# Scanned 4600 chunks, 38,587,596,800 decompressed bytes...
# Scanned 4620 chunks, 38,755,368,960 decompressed bytes...
# Scanned 4640 chunks, 38,923,141,120 decompressed bytes...
# Scanned 4660 chunks, 39,090,913,280 decompressed bytes...
# Scanned 4680 chunks, 39,258,685,440 decompressed bytes...
# Scanned 4700 chunks, 39,426,457,600 decompressed bytes...
# Scanned 4720 chunks, 39,594,229,760 decompressed bytes...
# Scanned 4740 chunks, 39,762,001,920 decompressed bytes...
# Scanned 4760 chunks, 39,929,774,080 decompressed bytes...
# Scanned 4780 chunks, 40,097,546,240 decompressed bytes...
# Scanned 4800 chunks, 40,265,318,400 decompressed bytes...
# Scanned 4820 chunks, 40,433,090,560 decompressed bytes...
# Scanned 4840 chunks, 40,600,862,720 decompressed bytes...
# Scanned 4860 chunks, 40,768,634,880 decompressed bytes...
# Scanned 4880 chunks, 40,936,407,040 decompressed bytes...
# Scanned 4900 chunks, 41,104,179,200 decompressed bytes...
# Scanned 4920 chunks, 41,271,951,360 decompressed bytes...
# Scanned 4940 chunks, 41,439,723,520 decompressed bytes...
# Scanned 4960 chunks, 41,607,495,680 decompressed bytes...
# Scanned 4980 chunks, 41,775,267,840 decompressed bytes...
# Scanned 5000 chunks, 41,943,040,000 decompressed bytes...
# Scanned 5020 chunks, 42,110,812,160 decompressed bytes...
# Scanned 5040 chunks, 42,278,584,320 decompressed bytes...
# Scanned 5060 chunks, 42,446,356,480 decompressed bytes...
# Scanned 5080 chunks, 42,614,128,640 decompressed bytes...
# Scanned 5100 chunks, 42,781,900,800 decompressed bytes...
# Scanned 5120 chunks, 42,949,672,960 decompressed bytes...
# Scanned 5140 chunks, 43,117,445,120 decompressed bytes...
# Scanned 5160 chunks, 43,285,217,280 decompressed bytes...
# Scanned 5180 chunks, 43,452,989,440 decompressed bytes...
# Scanned 5200 chunks, 43,620,761,600 decompressed bytes...
# Scanned 5220 chunks, 43,788,533,760 decompressed bytes...
# Scanned 5240 chunks, 43,956,305,920 decompressed bytes...
# Scanned 5260 chunks, 44,124,078,080 decompressed bytes...
# Scanned 5280 chunks, 44,291,850,240 decompressed bytes...
# Scanned 5300 chunks, 44,459,622,400 decompressed bytes...
# Scanned 5320 chunks, 44,627,394,560 decompressed bytes...
# Scanned 5340 chunks, 44,795,166,720 decompressed bytes...
# Scanned 5360 chunks, 44,962,938,880 decompressed bytes...
# Scanned 5380 chunks, 45,130,711,040 decompressed bytes...
# Scanned 5400 chunks, 45,298,483,200 decompressed bytes...
# Scanned 5420 chunks, 45,466,255,360 decompressed bytes...
# Scanned 5440 chunks, 45,634,027,520 decompressed bytes...
# Scanned 5460 chunks, 45,801,799,680 decompressed bytes...
# Scanned 5480 chunks, 45,969,571,840 decompressed bytes...
# Scanned 5500 chunks, 46,137,344,000 decompressed bytes...
# Scanned 5520 chunks, 46,305,116,160 decompressed bytes...
# Scanned 5540 chunks, 46,472,888,320 decompressed bytes...
# Scanned 5560 chunks, 46,640,660,480 decompressed bytes...
# Scanned 5580 chunks, 46,808,432,640 decompressed bytes...
# Scanned 5600 chunks, 46,976,204,800 decompressed bytes...
# Scanned 5620 chunks, 47,143,976,960 decompressed bytes...
# Scanned 5640 chunks, 47,311,749,120 decompressed bytes...
# Scanned 5660 chunks, 47,479,521,280 decompressed bytes...
# Scanned 5680 chunks, 47,647,293,440 decompressed bytes...
# Scanned 5700 chunks, 47,815,065,600 decompressed bytes...
# Scanned 5720 chunks, 47,982,837,760 decompressed bytes...
# Scanned 5740 chunks, 48,150,609,920 decompressed bytes...
# Scanned 5760 chunks, 48,318,382,080 decompressed bytes...
# Scanned 5780 chunks, 48,486,154,240 decompressed bytes...
# Scanned 5800 chunks, 48,653,926,400 decompressed bytes...
# Scanned 5820 chunks, 48,821,698,560 decompressed bytes...
# Scanned 5840 chunks, 48,989,470,720 decompressed bytes...
# Scanned 5860 chunks, 49,157,242,880 decompressed bytes...
# Scanned 5880 chunks, 49,325,015,040 decompressed bytes...
# Scanned 5900 chunks, 49,492,787,200 decompressed bytes...
# Scanned 5920 chunks, 49,660,559,360 decompressed bytes...
# Scanned 5940 chunks, 49,828,331,520 decompressed bytes...
# Scanned 5960 chunks, 49,996,103,680 decompressed bytes...
# Scanned 5980 chunks, 50,163,875,840 decompressed bytes...
# Scanned 6000 chunks, 50,331,648,000 decompressed bytes...
# Scanned 6020 chunks, 50,499,420,160 decompressed bytes...
# Scanned 6040 chunks, 50,667,192,320 decompressed bytes...
# Scanned 6060 chunks, 50,834,964,480 decompressed bytes...
# Scanned 6080 chunks, 51,002,736,640 decompressed bytes...
# Scanned 6100 chunks, 51,170,508,800 decompressed bytes...
# Scanned 6120 chunks, 51,338,280,960 decompressed bytes...
# Scanned 6140 chunks, 51,506,053,120 decompressed bytes...
# Scanned 6160 chunks, 51,673,825,280 decompressed bytes...
# Scanned 6180 chunks, 51,841,597,440 decompressed bytes...
# Scanned 6200 chunks, 52,009,369,600 decompressed bytes...
# Scanned 6220 chunks, 52,177,141,760 decompressed bytes...
# Scanned 6240 chunks, 52,344,913,920 decompressed bytes...
# Scanned 6260 chunks, 52,512,686,080 decompressed bytes...
# Scanned 6280 chunks, 52,680,458,240 decompressed bytes...
# Scanned 6300 chunks, 52,848,230,400 decompressed bytes...
# Scanned 6320 chunks, 53,016,002,560 decompressed bytes...
# Scanned 6340 chunks, 53,183,774,720 decompressed bytes...
# Scanned 6360 chunks, 53,351,546,880 decompressed bytes...
# Scanned 6380 chunks, 53,519,319,040 decompressed bytes...
# Scanned 6400 chunks, 53,687,091,200 decompressed bytes...
# Scanned 6420 chunks, 53,854,863,360 decompressed bytes...
# Scanned 6440 chunks, 54,022,635,520 decompressed bytes...
# Scanned 6460 chunks, 54,190,407,680 decompressed bytes...
# Scanned 6480 chunks, 54,358,179,840 decompressed bytes...
# Scanned 6500 chunks, 54,525,952,000 decompressed bytes...
# Scanned 6520 chunks, 54,693,724,160 decompressed bytes...
# Scanned 6540 chunks, 54,861,496,320 decompressed bytes...
# Scanned 6560 chunks, 55,029,268,480 decompressed bytes...
# Scanned 6580 chunks, 55,197,040,640 decompressed bytes...
# Scanned 6600 chunks, 55,364,812,800 decompressed bytes...
# Scanned 6620 chunks, 55,532,584,960 decompressed bytes...
# Scanned 6640 chunks, 55,700,357,120 decompressed bytes...
# Scanned 6660 chunks, 55,868,129,280 decompressed bytes...
# Scanned 6680 chunks, 56,035,901,440 decompressed bytes...
# Scanned 6700 chunks, 56,203,673,600 decompressed bytes...
# Scanned 6720 chunks, 56,371,445,760 decompressed bytes...
# Scanned 6740 chunks, 56,539,217,920 decompressed bytes...
# Scanned 6760 chunks, 56,706,990,080 decompressed bytes...
# Scanned 6780 chunks, 56,874,762,240 decompressed bytes...
# Scanned 6800 chunks, 57,042,534,400 decompressed bytes...
# Scanned 6820 chunks, 57,210,306,560 decompressed bytes...
# Scanned 6840 chunks, 57,378,078,720 decompressed bytes...
# Scanned 6860 chunks, 57,545,850,880 decompressed bytes...
# Scanned 6880 chunks, 57,713,623,040 decompressed bytes...
# Scanned 6900 chunks, 57,881,395,200 decompressed bytes...
# Scanned 6920 chunks, 58,049,167,360 decompressed bytes...
# Scanned 6940 chunks, 58,216,939,520 decompressed bytes...
# Scanned 6960 chunks, 58,384,711,680 decompressed bytes...
# Scanned 6980 chunks, 58,552,483,840 decompressed bytes...
# Scanned 7000 chunks, 58,720,256,000 decompressed bytes...
# Scanned 7020 chunks, 58,888,028,160 decompressed bytes...
# Scanned 7040 chunks, 59,055,800,320 decompressed bytes...
# Scanned 7060 chunks, 59,223,572,480 decompressed bytes...
# Scanned 7080 chunks, 59,391,344,640 decompressed bytes...
# Scanned 7100 chunks, 59,559,116,800 decompressed bytes...
# Scanned 7120 chunks, 59,726,888,960 decompressed bytes...
# Scanned 7140 chunks, 59,894,661,120 decompressed bytes...
# Scanned 7160 chunks, 60,062,433,280 decompressed bytes...
# Scanned 7180 chunks, 60,230,205,440 decompressed bytes...
# Scanned 7200 chunks, 60,397,977,600 decompressed bytes...
# Scanned 7220 chunks, 60,565,749,760 decompressed bytes...
# Scanned 7240 chunks, 60,733,521,920 decompressed bytes...
# Scanned 7260 chunks, 60,901,294,080 decompressed bytes...
# Scanned 7280 chunks, 61,069,066,240 decompressed bytes...
# Scanned 7300 chunks, 61,236,838,400 decompressed bytes...
# Scanned 7320 chunks, 61,404,610,560 decompressed bytes...
# Scanned 7340 chunks, 61,572,382,720 decompressed bytes...
# Scanned 7360 chunks, 61,740,154,880 decompressed bytes...
# Scanned 7380 chunks, 61,907,927,040 decompressed bytes...
# Scanned 7400 chunks, 62,075,699,200 decompressed bytes...
# Scanned 7420 chunks, 62,243,471,360 decompressed bytes...
# Scanned 7440 chunks, 62,411,243,520 decompressed bytes...
# Scanned 7460 chunks, 62,579,015,680 decompressed bytes...
# Scanned 7480 chunks, 62,746,787,840 decompressed bytes...
# Scanned 7500 chunks, 62,914,560,000 decompressed bytes...
# Scanned 7520 chunks, 63,082,332,160 decompressed bytes...
# Scanned 7540 chunks, 63,250,104,320 decompressed bytes...
# Scanned 7560 chunks, 63,417,876,480 decompressed bytes...
# Scanned 7580 chunks, 63,585,648,640 decompressed bytes...
# Scanned 7600 chunks, 63,753,420,800 decompressed bytes...
# Scanned 7620 chunks, 63,921,192,960 decompressed bytes...
# Scanned 7640 chunks, 64,088,965,120 decompressed bytes...
# Scanned 7660 chunks, 64,256,737,280 decompressed bytes...
# Scanned 7680 chunks, 64,424,509,440 decompressed bytes...
# Scanned 7700 chunks, 64,592,281,600 decompressed bytes...
# Scanned 7720 chunks, 64,760,053,760 decompressed bytes...
# Scanned 7740 chunks, 64,927,825,920 decompressed bytes...
# Scanned 7760 chunks, 65,095,598,080 decompressed bytes...
# Scanned 7780 chunks, 65,263,370,240 decompressed bytes...
# Scanned 7800 chunks, 65,431,142,400 decompressed bytes...
# Scanned 7820 chunks, 65,598,914,560 decompressed bytes...
# Scanned 7840 chunks, 65,766,686,720 decompressed bytes...
# Scanned 7860 chunks, 65,934,458,880 decompressed bytes...
# Scanned 7880 chunks, 66,102,231,040 decompressed bytes...
# Scanned 7900 chunks, 66,270,003,200 decompressed bytes...
# Scanned 7920 chunks, 66,437,775,360 decompressed bytes...
# Scanned 7940 chunks, 66,605,547,520 decompressed bytes...
# Scanned 7960 chunks, 66,773,319,680 decompressed bytes...
# Scanned 7980 chunks, 66,941,091,840 decompressed bytes...
# Scanned 8000 chunks, 67,108,864,000 decompressed bytes...
# (5,
#  [('reporting_entity_name',
#    KeyHit(key='reporting_entity_name', abs_offset=1, chunk_index=0, offset_in_chunk=1)),
#   ('reporting_entity_type',
#    KeyHit(key='reporting_entity_type', abs_offset=56, chunk_index=0, offset_in_chunk=56)),
#   ('last_updated_on',
#    KeyHit(key='last_updated_on', abs_offset=108, chunk_index=0, offset_in_chunk=108)),
#   ('version',
#    KeyHit(key='version', abs_offset=140, chunk_index=0, offset_in_chunk=140)),
#   ('in_network',
#    KeyHit(key='in_network', abs_offset=62964453082, chunk_index=7505, offset_in_chunk=7950042))])

# %%
unique_hits
# Out:
# {'reporting_entity_name': KeyHit(key='reporting_entity_name', abs_offset=1, chunk_index=0, offset_in_chunk=1),
#  'reporting_entity_type': KeyHit(key='reporting_entity_type', abs_offset=56, chunk_index=0, offset_in_chunk=56),
#  'last_updated_on': KeyHit(key='last_updated_on', abs_offset=108, chunk_index=0, offset_in_chunk=108),
#  'version': KeyHit(key='version', abs_offset=140, chunk_index=0, offset_in_chunk=140),
#  'in_network': KeyHit(key='in_network', abs_offset=62964453082, chunk_index=7505, offset_in_chunk=7950042)}

# %%
def read_window_at_decompressed_offset(
    gz_path: str,
    abs_offset: int,
    index_path: Optional[str] = None,
    window: int = 4096,
):
    if index_path:
        f = open_with_existing_index(gz_path, index_path)
    else:
        f = open_indexed_gzip(gz_path)

    f.seek(abs_offset)
    data = f.read(window)
    f.close()
    return data

# %%
def read_span_between_offsets(
    f,
    start_offset: int,
    end_offset: int | None,
    extra: int = 256,
    max_bytes: int = 16 * 1024 * 1024,  # safety cap
) -> bytes:
    if start_offset < 0:
        raise ValueError("start_offset must be >= 0")

    f.seek(start_offset)

    if end_offset is not None:
        if end_offset <= start_offset:
            raise ValueError("end_offset must be greater than start_offset")
        n = (end_offset - start_offset) + extra
        return f.read(n)

    # end_offset is None → bounded read
    return f.read(max_bytes)

# %%
def _parse_up_to_n_array_elements_best_effort(text: str, array_start_idx: int, n: int):
    """
    Best-effort parse of up to n elements from a JSON array starting at '['.
    Returns a list with 0..n elements depending on how much is available in `text`.
    Never raises due to truncation; it stops when it can't continue.
    """
    assert text[array_start_idx] == "["
    decoder = json.JSONDecoder()

    i = array_start_idx + 1  # after '['
    out = []

    def skip_ws(idx):
        while idx < len(text) and text[idx].isspace():
            idx += 1
        return idx

    i = skip_ws(i)

    # Empty array
    if i < len(text) and text[i] == "]":
        return []

    while len(out) < n:
        i = skip_ws(i)
        if i >= len(text):
            break

        # End of array
        if text[i] == "]":
            break

        # Attempt decode one element; if fails (likely truncation), stop
        try:
            val, consumed = decoder.raw_decode(text[i:])
        except Exception:
            break

        out.append(val)
        i += consumed

        i = skip_ws(i)
        if i >= len(text):
            break

        # Consume delimiter if present; if not, stop best-effort
        if text[i] == ",":
            i += 1
            continue
        elif text[i] == "]":
            break
        else:
            break

    return out


def extract_scalar_or_first_n_from_span(key: str, span_bytes: bytes, n: int = 5):
    """
    Best-effort extraction from span_bytes containing '"key": <value>'.

    Behavior:
      - If key not found in span_bytes: return None
      - If value is scalar and fully present: return scalar
      - If scalar is truncated/unparseable: return None
      - If value is array: return up to first n elements that can be parsed (0..n)
        If array elements are truncated: returns what it can (possibly [])
    """
    if not span_bytes:
        return None

    key_bytes = b'"' + key.encode("utf-8") + b'"'

    # Find the key in raw bytes
    p = span_bytes.find(key_bytes)
    if p < 0:
        return None

    # Find colon after the key
    c = span_bytes.find(b":", p + len(key_bytes))
    if c < 0:
        return None

    # Move to first non-whitespace after colon
    i = c + 1
    L = len(span_bytes)
    while i < L and span_bytes[i] in b" \t\r\n":
        i += 1
    if i >= L:
        return None

    first = span_bytes[i:i+1]

    # Decode a working text view from value-start onward
    # (If there are encoding issues earlier in the span, we avoid them by decoding from i forward.)
    tail_bytes = span_bytes[i:]

    try:
        tail_text = tail_bytes.decode("utf-8", errors="strict")
    except UnicodeDecodeError:
        tail_text = tail_bytes.decode("utf-8", errors="replace")

    decoder = json.JSONDecoder()

    # Array case: parse up to n elements best-effort
    if first == b"[":
        # We decode from '[' onward, so index 0 is '['
        t = tail_text
        if not t or t[0] != "[":
            return []

        out = []
        pos = 1  # after '['

        def skip_ws(s, j):
            while j < len(s) and s[j].isspace():
                j += 1
            return j

        pos = skip_ws(t, pos)

        # Empty array
        if pos < len(t) and t[pos] == "]":
            return []

        while len(out) < n:
            pos = skip_ws(t, pos)
            if pos >= len(t):
                break
            if t[pos] == "]":
                break

            try:
                val, consumed = decoder.raw_decode(t[pos:])
            except Exception:
                # truncated or invalid element
                break

            out.append(val)
            pos += consumed
            pos = skip_ws(t, pos)

            if pos >= len(t):
                break
            if t[pos] == ",":
                pos += 1
                continue
            if t[pos] == "]":
                break

            # Unexpected delimiter → stop best-effort
            break

        return out

    # Scalar/object case: parse one JSON value best-effort
    try:
        value, _ = decoder.raw_decode(tail_text)
    except Exception:
        return None

    # If you truly only want scalars (not dict/list), enforce:
    if isinstance(value, (list, dict)):
        return None

    return value

# %%
targets = list(unique_hits.items())
for i, (key_name, hit) in enumerate(targets):
    start = hit.abs_offset

    # Determine end offset (next key's start, or None for last key)
    try:
        next_hit = targets[i + 1][1]
        end = next_hit.abs_offset
    except IndexError:
        end = None  # Last key, no end boundary
    print(key_name)
    print(start,end)
    # Read span and extract value
#     span = read_span_between_offsets(f, start, end, extra=512)
#     val = extract_scalar_or_first_n_from_span(key_name, span, n=1)
# Out:
# reporting_entity_name
# 1 56
# reporting_entity_type
# 56 108
# last_updated_on
# 108 140
# version
# 140 62964453082
# in_network
# 62964453082 None

# %%
val[0]
# Out:
# {'negotiation_arrangement': 'ffs',
#  'name': 'dmin influenza virus vac',
#  'billing_code_type': 'HCPCS',
#  'billing_code_type_version': '2025',
#  'billing_code': 'G0008',
#  'description': 'Administration of Influenza Virus Vaccine',
#  'negotiated_rates': [{'provider_groups': [{'npi': [1699730218],
#      'tin': {'type': 'ein', 'value': '20-0336147'}},
#     {'npi': [1780799684], 'tin': {'type': 'ein', 'value': '27-1913972'}},
#     {'npi': [1538572144, 1235340779, 1588616551],
#      'tin': {'type': 'ein', 'value': '43-1980122'}},
#     {'npi': [1114033016, 1346509718, 1669057535],
#      'tin': {'type': 'ein', 'value': '47-3756681'}},
#     {'npi': [1891880928, 1518910892],
#      'tin': {'type': 'ein', 'value': '63-0697924'}},
#     {'npi': [1114362688,
#       1174943138,
#       1740283266,
#       1528379716,
#       1386847374,
#       1861495384],
#      'tin': {'type': 'ein', 'value': '63-0772886'}},
#     {'npi': [1366570640, 1528052818, 1518317106, 1033103189],
#      'tin': {'type': 'ein', 'value': '63-0795136'}},
#     {'npi': [1598728925], 'tin': {'type': 'ein', 'value': '63-1014137'}},
#     {'npi': [1447299987, 1659637684],
#      'tin': {'type': 'ein', 'value': '63-1245254'}},
#     {'npi': [1144545740], 'tin': {'type': 'ein', 'value': '84-4615780'}},
#     {'npi': [1841017530], 'tin': {'type': 'ein', 'value': '87-4076704'}},
#     {'npi': [1225040074, 1740546365],
#      'tin': {'type': 'ein', 'value': '99-2278264'}}],
#    'negotiated_prices': [{'negotiated_type': 'negotiated',
#      'negotiated_rate': 19.11,
#      'expiration_date': '9999-12-31',
#      'service_code': ['11'],
#      'billing_class': 'professional'}]},
#   {'provider_groups': [{'npi': [1114212008],
#      'tin': {'type': 'ein', 'value': '01-0598195'}},
#     {'npi': [1104891761, 1144295718],
#      'tin': {'type': 'ein', 'value': '01-0781275'}},
#     {'npi': [1164499398], 'tin': {'type': 'ein', 'value': '02-0753689'}},
#     {'npi': [1639280571], 'tin': {'type': 'ein', 'value': '04-3732763'}},
#     {'npi': [1316982143], 'tin': {'type': 'ein', 'value': '06-1711898'}},
#     {'npi': [1255508743], 'tin': {'type': 'ein', 'value': '11-3838194'}},
#     {'npi': [1609104736, 1639160708],
#      'tin': {'type': 'ein', 'value': '13-4211220'}},
#     {'npi': [1942298740], 'tin': {'type': 'ein', 'value': '16-1634677'}},
#     {'npi': [1407842065], 'tin': {'type': 'ein', 'value': '20-0209540'}},
#     {'npi': [1760418370], 'tin': {'type': 'ein', 'value': '20-0391730'}},
#     {'npi': [1700802147], 'tin': {'type': 'ein', 'value': '20-0595020'}},
#     {'npi': [1710987144], 'tin': {'type': 'ein', 'value': '20-0891807'}},
#     {'npi': [1164535274], 'tin': {'type': 'ein', 'value': '20-1121194'}},
#     {'npi': [1972526861], 'tin': {'type': 'ein', 'value': '20-1239278'}},
#     {'npi': [1750330361], 'tin': {'type': 'ein', 'value': '20-2148696'}},
#     {'npi': [1225729510, 1972580736, 1093502486],
#      'tin': {'type': 'ein', 'value': '20-2289103'}},
#     {'npi': [1871626168], 'tin': {'type': 'ein', 'value': '20-3125197'}},
#     {'npi': [1891196432, 1245221092],
#      'tin': {'type': 'ein', 'value': '20-3215567'}},
#     {'npi': [1700542065, 1811238751],
#      'tin': {'type': 'ein', 'value': '20-3317009'}},
#     {'npi': [1649719030], 'tin': {'type': 'ein', 'value': '20-3319340'}},
#     {'npi': [1942617162], 'tin': {'type': 'ein', 'value': '20-3577291'}},
#     {'npi': [1831110659], 'tin': {'type': 'ein', 'value': '20-3943061'}},
#     {'npi': [1902205099], 'tin': {'type': 'ein', 'value': '20-3946804'}},
#     {'npi': [1003842345], 'tin': {'type': 'ein', 'value': '20-4763483'}},
#     {'npi': [1114965209], 'tin': {'type': 'ein', 'value': '20-4881357'}},
#     {'npi': [1639678816], 'tin': {'type': 'ein', 'value': '20-4986869'}},
#     {'npi': [1255617569], 'tin': {'type': 'ein', 'value': '20-5063536'}},
#     {'npi': [1508394339], 'tin': {'type': 'ein', 'value': '20-5132648'}},
#     {'npi': [1730681750], 'tin': {'type': 'ein', 'value': '20-5179677'}},
#     {'npi': [1053344556], 'tin': {'type': 'ein', 'value': '20-5277582'}},
#     {'npi': [1518096700], 'tin': {'type': 'ein', 'value': '20-5342682'}},
#     {'npi': [1154492163], 'tin': {'type': 'ein', 'value': '20-5536857'}},
#     {'npi': [1043366800], 'tin': {'type': 'ein', 'value': '20-8046135'}},
#     {'npi': [1447445820], 'tin': {'type': 'ein', 'value': '20-8184257'}},
#     {'npi': [1407908437], 'tin': {'type': 'ein', 'value': '20-8209626'}},
#     {'npi': [1407000292], 'tin': {'type': 'ein', 'value': '22-2862167'}},
#     {'npi': [1669062378], 'tin': {'type': 'ein', 'value': '23-2483463'}},
#     {'npi': [1275851800], 'tin': {'type': 'ein', 'value': '23-2736822'}},
#     {'npi': [1538118278], 'tin': {'type': 'ein', 'value': '26-0015059'}},
#     {'npi': [1689077042], 'tin': {'type': 'ein', 'value': '26-0059374'}},
#     {'npi': [1942482229], 'tin': {'type': 'ein', 'value': '26-0728690'}},
#     {'npi': [1841479573], 'tin': {'type': 'ein', 'value': '26-0852085'}},
#     {'npi': [1427222470], 'tin': {'type': 'ein', 'value': '26-2423030'}},
#     {'npi': [1861726440], 'tin': {'type': 'ein', 'value': '26-2824875'}},
#     {'npi': [1245214006], 'tin': {'type': 'ein', 'value': '26-3644408'}},
#     {'npi': [1912145541], 'tin': {'type': 'ein', 'value': '26-4004863'}},
#     {'npi': [1407096290], 'tin': {'type': 'ein', 'value': '26-4051654'}},
#     {'npi': [1245225812], 'tin': {'type': 'ein', 'value': '26-4126712'}},
#     {'npi': [1851371033], 'tin': {'type': 'ein', 'value': '26-4439292'}},
#     {'npi': [1366757338], 'tin': {'type': 'ein', 'value': '26-4710104'}},
#     {'npi': [1932483831], 'tin': {'type': 'ein', 'value': '27-2452671'}},
#     {'npi': [1316356942], 'tin': {'type': 'ein', 'value': '27-3719229'}},
#     {'npi': [1013211499], 'tin': {'type': 'ein', 'value': '27-3952181'}},
#     {'npi': [1356750574], 'tin': {'type': 'ein', 'value': '31-1651314'}},
#     {'npi': [1780646307], 'tin': {'type': 'ein', 'value': '32-0044462'}},
#     {'npi': [1851309512, 1720195746],
#      'tin': {'type': 'ein', 'value': '33-0057155'}},
#     {'npi': [1235310699], 'tin': {'type': 'ein', 'value': '33-0350172'}},
#     {'npi': [1124376652], 'tin': {'type': 'ein', 'value': '33-0689760'}},
#     {'npi': [1023425378], 'tin': {'type': 'ein', 'value': '33-0989359'}},
#     {'npi': [1184602518], 'tin': {'type': 'ein', 'value': '34-1174227'}},
#     {'npi': [1457310492], 'tin': {'type': 'ein', 'value': '35-2011651'}},
#     {'npi': [1558444810], 'tin': {'type': 'ein', 'value': '36-4391413'}},
#     {'npi': [1831260512], 'tin': {'type': 'ein', 'value': '38-3030206'}},
#     {'npi': [1427451582], 'tin': {'type': 'ein', 'value': '38-3939726'}},
#     {'npi': [1326178328], 'tin': {'type': 'ein', 'value': '39-2012203'}},
#     {'npi': [1184021594], 'tin': {'type': 'ein', 'value': '41-1419350'}},
#     {'npi': [1821030909], 'tin': {'type': 'ein', 'value': '41-1732920'}},
#     {'npi': [1427131424], 'tin': {'type': 'ein', 'value': '41-1801204'}},
#     {'npi': [1235989658, 1992376982, 1093792863],
#      'tin': {'type': 'ein', 'value': '41-2062449'}},
#     {'npi': [1710399266], 'tin': {'type': 'ein', 'value': '41-2207549'}},
#     {'npi': [1962620419], 'tin': {'type': 'ein', 'value': '41-7028154'}},
#     {'npi': [1720337835, 1427451236],
#      'tin': {'type': 'ein', 'value': '43-1922598'}},
#     {'npi': [1871569129], 'tin': {'type': 'ein', 'value': '45-0495549'}},
#     {'npi': [1548548555], 'tin': {'type': 'ein', 'value': '45-2313324'}},
#     {'npi': [1548551260], 'tin': {'type': 'ein', 'value': '45-2603224'}},
#     {'npi': [1447518543], 'tin': {'type': 'ein', 'value': '45-3543284'}},
#     {'npi': [1861761785], 'tin': {'type': 'ein', 'value': '45-3935628'}},
#     {'npi': [1851381958], 'tin': {'type': 'ein', 'value': '45-5179267'}},
#     {'npi': [1437407715], 'tin': {'type': 'ein', 'value': '46-0800577'}},
#     {'npi': [1841534195], 'tin': {'type': 'ein', 'value': '46-1443414'}},
#     {'npi': [1356687404], 'tin': {'type': 'ein', 'value': '46-1574442'}},
#     {'npi': [1629854708, 1245685981, 1750736310, 1780921213],
#      'tin': {'type': 'ein', 'value': '46-1616372'}},
#     {'npi': [1831501493], 'tin': {'type': 'ein', 'value': '46-1870301'}},
#     {'npi': [1982030193], 'tin': {'type': 'ein', 'value': '46-3356780'}},
#     {'npi': [1942621016], 'tin': {'type': 'ein', 'value': '46-4298500'}},
#     {'npi': [1073919361, 1073917266],
#      'tin': {'type': 'ein', 'value': '46-5291153'}},
#     {'npi': [1013308618], 'tin': {'type': 'ein', 'value': '47-2930554'}},
#     {'npi': [1801444062], 'tin': {'type': 'ein', 'value': '47-3880082'}},
#     {'npi': [1891176517], 'tin': {'type': 'ein', 'value': '47-4234290'}},
#     {'npi': [1023464849], 'tin': {'type': 'ein', 'value': '47-4777440'}},
#     {'npi': [1255738498,
#       1427122308,
#       1306235973,
#       1356732200,
#       1558433292,
#       1730251471,
#       1255405304,
#       1942210489,
#       1205022043,
#       1336213214],
#      'tin': {'type': 'ein', 'value': '52-1486235'}},
#     {'npi': [1497731533], 'tin': {'type': 'ein', 'value': '52-2165554'}},
#     {'npi': [1831263110], 'tin': {'type': 'ein', 'value': '52-2280045'}},
#     {'npi': [1548678717], 'tin': {'type': 'ein', 'value': '56-2222382'}},
#     {'npi': [1144706136, 1982909743],
#      'tin': {'type': 'ein', 'value': '56-2436355'}},
#     {'npi': [1124865985, 1871773523, 1942911433],
#      'tin': {'type': 'ein', 'value': '56-2626647'}},
#     {'npi': [1073730602], 'tin': {'type': 'ein', 'value': '57-1171953'}},
#     {'npi': [1669452363], 'tin': {'type': 'ein', 'value': '58-1729882'}},
#     {'npi': [1508885617], 'tin': {'type': 'ein', 'value': '58-2509302'}},
#     {'npi': [1851489702], 'tin': {'type': 'ein', 'value': '58-2520839'}},
#     {'npi': [1417937152,
#       1629058912,
#       1396715074,
#       1871573600,
#       1992785794,
#       1922088806,
#       1164402855,
#       1588644264,
#       1003896747,
#       1427038637,
#       1073593778,
#       1912987223,
#       1992785208,
#       1245210525,
#       1457331134],
#      'tin': {'type': 'ein', 'value': '59-1450889'}},
#     {'npi': [1992037089,
#       1265510531,
#       1487732806,
#       1023340106,
#       1306081930,
#       1033297452,
#       1770600942,
#       1154653236,
#       1427380500,
#       1649352949,
#       1023179991,
#       1003977976,
#       1841416542],
#      'tin': {'type': 'ein', 'value': '59-2852900'}},
#     {'npi': [1487624334], 'tin': {'type': 'ein', 'value': '59-2893038'}},
#     {'npi': [1972564045], 'tin': {'type': 'ein', 'value': '59-2932598'}},
#     {'npi': [1447211446], 'tin': {'type': 'ein', 'value': '59-2957024'}},
#     {'npi': [1770552218, 1467421941, 1568431062],
#      'tin': {'type': 'ein', 'value': '59-2973806'}},
#     {'npi': [1851702583], 'tin': {'type': 'ein', 'value': '59-3123992'}},
#     {'npi': [1225018963], 'tin': {'type': 'ein', 'value': '59-3143941'}},
#     {'npi': [1093795890], 'tin': {'type': 'ein', 'value': '59-3221497'}},
#     {'npi': [1295827780], 'tin': {'type': 'ein', 'value': '59-3271823'}},
#     {'npi': [1275594202, 1598726523, 1912968942, 1669433694],
#      'tin': {'type': 'ein', 'value': '59-3279824'}},
#     {'npi': [1578881702], 'tin': {'type': 'ein', 'value': '59-3323767'}},
#     {'npi': [1609846773], 'tin': {'type': 'ein', 'value': '59-3334408'}},
#     {'npi': [1154462026], 'tin': {'type': 'ein', 'value': '59-3437644'}},
#     {'npi': [1407935950], 'tin': {'type': 'ein', 'value': '59-3609268'}},
#     {'npi': [1649375460], 'tin': {'type': 'ein', 'value': '59-3613176'}},
#     {'npi': [1023419827], 'tin': {'type': 'ein', 'value': '61-1339483'}},
#     {'npi': [1558334474, 1548235260],
#      'tin': {'type': 'ein', 'value': '62-1400785'}},
#     {'npi': [1083195663], 'tin': {'type': 'ein', 'value': '62-1763595'}},
#     {'npi': [1932122314], 'tin': {'type': 'ein', 'value': '63-0288894'}},
#     {'npi': [1174573547], 'tin': {'type': 'ein', 'value': '63-0288981'}},
#     {'npi': [1801846126], 'tin': {'type': 'ein', 'value': '63-0297932'}},
#     {'npi': [1962402693], 'tin': {'type': 'ein', 'value': '63-0415340'}},
#     {'npi': [1992132864,
#       1619932001,
#       1417229196,
#       1740794734,
#       1649399502,
#       1528632502,
#       1861142143],
#      'tin': {'type': 'ein', 'value': '63-0460791'}},
#     {'npi': [1558787929, 1528089604],
#      'tin': {'type': 'ein', 'value': '63-0480130'}},
#     {'npi': [1417148164], 'tin': {'type': 'ein', 'value': '63-0500139'}},
#     {'npi': [1174524169], 'tin': {'type': 'ein', 'value': '63-0500635'}},
#     {'npi': [1770635849], 'tin': {'type': 'ein', 'value': '63-0502107'}},
#     {'npi': [1376554907, 1285645812],
#      'tin': {'type': 'ein', 'value': '63-0513633'}},
#     {'npi': [1245276112], 'tin': {'type': 'ein', 'value': '63-0593990'}},
#     {'npi': [1841380086], 'tin': {'type': 'ein', 'value': '63-0649108'}},
#     {'npi': [1417021403], 'tin': {'type': 'ein', 'value': '63-0653583'}},
#     {'npi': [1437138377], 'tin': {'type': 'ein', 'value': '63-0701196'}},
#     {'npi': [1972585834,
#       1871770156,
#       1992787436,
#       1689656530,
#       1770569428,
#       1750363198],
#      'tin': {'type': 'ein', 'value': '63-0714407'}},
#     {'npi': [1295715167], 'tin': {'type': 'ein', 'value': '63-0719873'}},
#     {'npi': [1073551461], 'tin': {'type': 'ein', 'value': '63-0732734'}},
#     {'npi': [1376539874, 1548256621],
#      'tin': {'type': 'ein', 'value': '63-0733300'}},
#     {'npi': [1124125349], 'tin': {'type': 'ein', 'value': '63-0740395'}},
#     {'npi': [1154354181], 'tin': {'type': 'ein', 'value': '63-0766033'}},
#     {'npi': [1306812458], 'tin': {'type': 'ein', 'value': '63-0772945'}},
#     {'npi': [1518912948, 1881644524],
#      'tin': {'type': 'ein', 'value': '63-0777070'}},
#     {'npi': [1780731240, 1225069420, 1528169109],
#      'tin': {'type': 'ein', 'value': '63-0804729'}},
#     {'npi': [1043269046], 'tin': {'type': 'ein', 'value': '63-0810292'}},
#     {'npi': [1134110968, 1437208261],
#      'tin': {'type': 'ein', 'value': '63-0829348'}},
#     {'npi': [1992871842, 1376679308],
#      'tin': {'type': 'ein', 'value': '63-0849662'}},
#     {'npi': [1376860312], 'tin': {'type': 'ein', 'value': '63-0871557'}},
#     {'npi': [1255380226], 'tin': {'type': 'ein', 'value': '63-0894060'}},
#     {'npi': [1407814312, 1831121623],
#      'tin': {'type': 'ein', 'value': '63-0897013'}},
#     {'npi': [1306101639], 'tin': {'type': 'ein', 'value': '63-0897255'}},
#     {'npi': [1699052464, 1972880748],
#      'tin': {'type': 'ein', 'value': '63-0904463'}},
#     {'npi': [1013007236], 'tin': {'type': 'ein', 'value': '63-0908374'}},
#     {'npi': [1508852815], 'tin': {'type': 'ein', 'value': '63-0912836'}},
#     {'npi': [1659332047], 'tin': {'type': 'ein', 'value': '63-0937802'}},
#     {'npi': [1417091042], 'tin': {'type': 'ein', 'value': '63-0953685'}},
#     {'npi': [1760468466, 1225320773],
#      'tin': {'type': 'ein', 'value': '63-0955885'}},
#     {'npi': [1609948736], 'tin': {'type': 'ein', 'value': '63-0976891'}},
#     {'npi': [1548262850], 'tin': {'type': 'ein', 'value': '63-1000459'}},
#     {'npi': [1306944269], 'tin': {'type': 'ein', 'value': '63-1020618'}},
#     {'npi': [1629173539, 1447357819, 1780781195],
#      'tin': {'type': 'ein', 'value': '63-1029699'}},
#     {'npi': [1073688594], 'tin': {'type': 'ein', 'value': '63-1041426'}},
#     {'npi': [1477614535], 'tin': {'type': 'ein', 'value': '63-1046891'}},
#     {'npi': [1205955218], 'tin': {'type': 'ein', 'value': '63-1047349'}},
#     {'npi': [1225048903], 'tin': {'type': 'ein', 'value': '63-1055226'}},
#     {'npi': [1679564256], 'tin': {'type': 'ein', 'value': '63-1058174'}},
#     {'npi': [1023161668], 'tin': {'type': 'ein', 'value': '63-1060091'}},
#     {'npi': [1134241961], 'tin': {'type': 'ein', 'value': '63-1065418'}},
#     {'npi': [1548367774], 'tin': {'type': 'ein', 'value': '63-1069197'}},
#     {'npi': [1851349823], 'tin': {'type': 'ein', 'value': '63-1071713'}},
#     {'npi': [1053320689, 1073659322],
#      'tin': {'type': 'ein', 'value': '63-1071999'}},
#     {'npi': [1093768491], 'tin': {'type': 'ein', 'value': '63-1075382'}},
#     {'npi': [1093887317], 'tin': {'type': 'ein', 'value': '63-1084735'}},
#     {'npi': [1669571048], 'tin': {'type': 'ein', 'value': '63-1084911'}},
#     {'npi': [1689663924], 'tin': {'type': 'ein', 'value': '63-1098354'}},
#     {'npi': [1962410449, 1154576916, 1932161445],
#      'tin': {'type': 'ein', 'value': '63-1107059'}},
#     {'npi': [1578513545], 'tin': {'type': 'ein', 'value': '63-1126150'}},
#     {'npi': [1407859127], 'tin': {'type': 'ein', 'value': '63-1129302'}},
#     {'npi': [1518054816], 'tin': {'type': 'ein', 'value': '63-1134860'}},
#     {'npi': [1942208681], 'tin': {'type': 'ein', 'value': '63-1158411'}},
#     {'npi': [1740287085], 'tin': {'type': 'ein', 'value': '63-1167013'}},
#     {'npi': [1619952447], 'tin': {'type': 'ein', 'value': '63-1173806'}},
#     {'npi': [1588670392], 'tin': {'type': 'ein', 'value': '63-1173955'}},
#     {'npi': [1942266499, 1023770476],
#      'tin': {'type': 'ein', 'value': '63-1176103'}},
#     {'npi': [1003825696], 'tin': {'type': 'ein', 'value': '63-1180459'}},
#     {'npi': [1871620526], 'tin': {'type': 'ein', 'value': '63-1181454'}},
#     {'npi': [1568494219], 'tin': {'type': 'ein', 'value': '63-1183513'}},
#     {'npi': [1912060740], 'tin': {'type': 'ein', 'value': '63-1188388'}},
#     {'npi': [1801886882], 'tin': {'type': 'ein', 'value': '63-1191196'}},
#     {'npi': [1376579912], 'tin': {'type': 'ein', 'value': '63-1194328'}},
#     {'npi': [1750367447], 'tin': {'type': 'ein', 'value': '63-1197315'}},
#     {'npi': [1932270600], 'tin': {'type': 'ein', 'value': '63-1209225'}},
#     {'npi': [1427222835], 'tin': {'type': 'ein', 'value': '63-1210092'}},
#     {'npi': [1730257536], 'tin': {'type': 'ein', 'value': '63-1215755'}},
#     {'npi': [1366517690], 'tin': {'type': 'ein', 'value': '63-1215916'}},
#     {'npi': [1487647210], 'tin': {'type': 'ein', 'value': '63-1231640'}},
#     {'npi': [1073511465], 'tin': {'type': 'ein', 'value': '63-1231716'}},
#     {'npi': [1669552329], 'tin': {'type': 'ein', 'value': '63-1233364'}},
#     {'npi': [1306896295], 'tin': {'type': 'ein', 'value': '63-1235631'}},
#     {'npi': [1720075807], 'tin': {'type': 'ein', 'value': '63-1241245'}},
#     {'npi': [1487632147, 1336127158],
#      'tin': {'type': 'ein', 'value': '63-1242375'}},
#     {'npi': [1093715849], 'tin': {'type': 'ein', 'value': '63-1250030'}},
#     {'npi': [1154340750], 'tin': {'type': 'ein', 'value': '63-1252716'}},
#     {'npi': [1114954294], 'tin': {'type': 'ein', 'value': '63-1270985'}},
#     {'npi': [1699047340, 1639495765, 1225014566],
#      'tin': {'type': 'ein', 'value': '63-1273339'}},
#     {'npi': [1477638211], 'tin': {'type': 'ein', 'value': '63-1278123'}},
#     {'npi': [1487781571], 'tin': {'type': 'ein', 'value': '63-1278571'}},
#     {'npi': [1912008277], 'tin': {'type': 'ein', 'value': '63-1279371'}},
#     {'npi': [1235112624, 1215229653],
#      'tin': {'type': 'ein', 'value': '63-1282810'}},
#     {'npi': [1689623514], 'tin': {'type': 'ein', 'value': '63-6000271'}},
#     {'npi': [1932662434], 'tin': {'type': 'ein', 'value': '63-6000526'}},
#     {'npi': [1235285867], 'tin': {'type': 'ein', 'value': '63-6002184'}},
#     {'npi': [1225041874], 'tin': {'type': 'ein', 'value': '63-6104957'}},
#     {'npi': [1104007632], 'tin': {'type': 'ein', 'value': '64-0667046'}},
#     {'npi': [1124127220], 'tin': {'type': 'ein', 'value': '64-0756777'}},
#     {'npi': [1760255442], 'tin': {'type': 'ein', 'value': '64-0793365'}},
#     {'npi': [1871812560], 'tin': {'type': 'ein', 'value': '64-0919329'}},
#     {'npi': [1053737627], 'tin': {'type': 'ein', 'value': '64-0936379'}},
#     {'npi': [1992891238], 'tin': {'type': 'ein', 'value': '65-1120748'}},
#     {'npi': [1912936030], 'tin': {'type': 'ein', 'value': '72-1362927'}},
#     {'npi': [1720008063], 'tin': {'type': 'ein', 'value': '72-1363465'}},
#     {'npi': [1316056138], 'tin': {'type': 'ein', 'value': '72-1363913'}},
#     {'npi': [1851308845], 'tin': {'type': 'ein', 'value': '72-1376092'}},
#     {'npi': [1609812411], 'tin': {'type': 'ein', 'value': '72-1382528'}},
#     {'npi': [1528179173], 'tin': {'type': 'ein', 'value': '72-1389973'}},
#     {'npi': [1013083450], 'tin': {'type': 'ein', 'value': '72-1391413'}},
#     {'npi': [1295740827], 'tin': {'type': 'ein', 'value': '72-1395274'}},
#     {'npi': [1770561599], 'tin': {'type': 'ein', 'value': '72-1522736'}},
#     {'npi': [1730103219], 'tin': {'type': 'ein', 'value': '72-1560188'}},
#     {'npi': [1124155262], 'tin': {'type': 'ein', 'value': '73-1649290'}},
#     {'npi': [1467861179], 'tin': {'type': 'ein', 'value': '75-2563782'}},
#     {'npi': [1235136060], 'tin': {'type': 'ein', 'value': '75-2608036'}},
#     {'npi': [1669721742], 'tin': {'type': 'ein', 'value': '75-3014671'}},
#     {'npi': [1356434906, 1699541516, 1508263575],
#      'tin': {'type': 'ein', 'value': '75-3039795'}},
#     {'npi': [1548367063], 'tin': {'type': 'ein', 'value': '75-3221011'}},
#     {'npi': [1477637601], 'tin': {'type': 'ein', 'value': '76-0715853'}},
#     {'npi': [1225139561], 'tin': {'type': 'ein', 'value': '76-0722683'}},
#     {'npi': [1417948258], 'tin': {'type': 'ein', 'value': '76-0777815'}},
#     {'npi': [1669189874], 'tin': {'type': 'ein', 'value': '80-0170309'}},
#     {'npi': [1396901047], 'tin': {'type': 'ein', 'value': '80-0213302'}},
#     {'npi': [1710293485], 'tin': {'type': 'ein', 'value': '80-0519106'}},
#     {'npi': [1649203365], 'tin': {'type': 'ein', 'value': '81-0862358'}},
#     {'npi': [1790221596], 'tin': {'type': 'ein', 'value': '81-0967479'}},
#     {'npi': [1386186674], 'tin': {'type': 'ein', 'value': '81-1991759'}},
#     {'npi': [1982159935], 'tin': {'type': 'ein', 'value': '81-2253336'}},
#     {'npi': [1255886834], 'tin': {'type': 'ein', 'value': '81-2551367'}},
#     {'npi': [1487117982], 'tin': {'type': 'ein', 'value': '81-3583194'}},
#     {'npi': [1023559473], 'tin': {'type': 'ein', 'value': '81-3848237'}},
#     {'npi': [1487170197], 'tin': {'type': 'ein', 'value': '81-5354153'}},
#     {'npi': [1780200493], 'tin': {'type': 'ein', 'value': '82-0946129'}},
#     {'npi': [1700548781], 'tin': {'type': 'ein', 'value': '82-1609230'}},
#     {'npi': [1316468515], 'tin': {'type': 'ein', 'value': '82-1675844'}},
#     {'npi': [1659881829], 'tin': {'type': 'ein', 'value': '82-2696926'}},
#     {'npi': [1750914552], 'tin': {'type': 'ein', 'value': '82-2943780'}},
#     {'npi': [1538658950], 'tin': {'type': 'ein', 'value': '82-3180376'}},
#     {'npi': [1013416155], 'tin': {'type': 'ein', 'value': '82-3984252'}},
#     {'npi': [1841795341], 'tin': {'type': 'ein', 'value': '82-4698593'}},
#     {'npi': [1326537945], 'tin': {'type': 'ein', 'value': '82-5438075'}},
#     {'npi': [1104856459, 1477568087],
#      'tin': {'type': 'ein', 'value': '83-0362786'}},
#     {'npi': [1700357910], 'tin': {'type': 'ein', 'value': '83-2702893'}},
#     {'npi': [1053976399], 'tin': {'type': 'ein', 'value': '83-3999574'}},
#     {'npi': [1255989307], 'tin': {'type': 'ein', 'value': '83-4538298'}},
#     {'npi': [1992327019], 'tin': {'type': 'ein', 'value': '84-1867294'}},
#     {'npi': [1215580964], 'tin': {'type': 'ein', 'value': '84-2427651'}},
#     {'npi': [1316021041], 'tin': {'type': 'ein', 'value': '84-3770494'}},
#     {'npi': [1124653423], 'tin': {'type': 'ein', 'value': '84-4672086'}},
#     {'npi': [1518610062], 'tin': {'type': 'ein', 'value': '85-0505732'}},
#     {'npi': [1770108342], 'tin': {'type': 'ein', 'value': '85-1063079'}},
#     {'npi': [1457966087], 'tin': {'type': 'ein', 'value': '85-2754399'}},
#     {'npi': [1457940777], 'tin': {'type': 'ein', 'value': '85-2856306'}},
#     {'npi': [1548026644], 'tin': {'type': 'ein', 'value': '87-3450430'}},
#     {'npi': [1144948928], 'tin': {'type': 'ein', 'value': '87-4836481'}},
#     {'npi': [1265153670], 'tin': {'type': 'ein', 'value': '88-3970629'}},
#     {'npi': [1093954844], 'tin': {'type': 'ein', 'value': '90-0495726'}},
#     {'npi': [1093412454], 'tin': {'type': 'ein', 'value': '92-1175800'}},
#     {'npi': [1942460423], 'tin': {'type': 'ein', 'value': '95-4662001'}},
#     {'npi': [1609858729], 'tin': {'type': 'ein', 'value': '34-1650951'}},
#     {'npi': [1093711996], 'tin': {'type': 'ein', 'value': '13-3683081'}},
#     {'npi': [1790730596], 'tin': {'type': 'ein', 'value': '94-3295573'}},
#     {'npi': [1811997638], 'tin': {'type': 'ein', 'value': '36-2596612'}},
#     {'npi': [1114177375], 'tin': {'type': 'ein', 'value': '63-0825248'}}],
#    'negotiated_prices': [{'negotiated_type': 'negotiated',
#      'negotiated_rate': 19.11,
#      'expiration_date': '9999-12-31',
#      'service_code': ['11',
#       '12',
#       '21',
#       '22',
#       '24',
#       '31',
#       '32',
#       '55',
#       '93',
#       '99'],
#      'billing_class': 'professional'}]},
#   {'provider_groups': [{'npi': [1336149426],
#      'tin': {'type': 'ein', 'value': '84-0945658'}}],
#    'negotiated_prices': [{'negotiated_type': 'negotiated',
#      'negotiated_rate': 20.55,
#      'expiration_date': '9999-12-31',
#      'service_code': ['11',
#       '12',
#       '21',
#       '22',
#       '24',
#       '31',
#       '32',
#       '55',
#       '93',
#       '99'],
#      'billing_class': 'professional'}]},
#   {'provider_groups': [{'npi': [0],
#      'tin': {'type': 'ein', 'value': '05-9224271'}},
#     {'npi': [1124521992,
#       1346690187,
#       1851374607,
#       1952367120,
#       1023091857,
#       1063776532,
#       1588839575,
#       1942283932,
#       1184087975,
#       1225473325,
#       1073960241,
#       1487637427,
#       1689794620,
#       1033479233,
#       1699162818,
#       1255314118,
#       1962683979,
#       1669505368,
#       1306870746,
#       1366429151,
#       1942397922,
#       1306829155,
#       1750656104,
#       1356324586,
#       1962485102,
#       1710097399],
#      'tin': {'type': 'ein', 'value': '26-4626109'}},
#     {'npi': [1578510145,
#       1659328227,
#       1679647267,
#       1225079783,
#       1740245927,
#       1396785929,
#       1770841223,
#       1417998071,
#       1659312171,
#       1346465549,
#       1013234830,
#       1003863598,
#       1598714750,
#       1023065687,
#       1326089913,
#       1831130459,
#       1710195516,
#       1598706046],
#      'tin': {'type': 'ein', 'value': '63-0313602'}},
#     {'npi': [1376563585,
#       1821052424,
#       1457730186,
#       1235344011,
#       1982051223,
#       1740600345,
#       1861673881,
#       1932162971,
#       1497958581,
#       1508829623,
#       1619930047,
#       1265540561,
#       1437611217,
#       1336646629,
#       1396900197,
#       1952515942,
#       1952693996,
#       1083677173,
#       1316434806,
#       1023071479,
#       1275596926,
#       1679634943],
#      'tin': {'type': 'ein', 'value': '63-1245407'}},
#     {'npi': [1720135684,
#       1689085573,
#       1467915017,
#       1346690187,
#       1932595980,
#       1851374607,
#       1952367120,
#       1023091857,
#       1578744595,
#       1063776532,
#       1780648212,
#       1588839575,
#       1720252315,
#       1407072028,
#       1942283932,
#       1417930660,
#       1164618278,
#       1184087975,
#       1861491367,
#       1225473325,
#       1952384943,
#       1073960241,
#       1487637427,
#       1174506166,
#       1689794620,
#       1386164671,
#       1033479233,
#       1699162818,
#       1255314118,
#       1962683979,
#       1053526988,
#       1386951887,
#       1104270420,
#       1669505368,
#       1306870746,
#       1912980954,
#       1366429151,
#       1508848607,
#       1033192034,
#       1306829155,
#       1669553764,
#       1710947684,
#       1760659684,
#       1942397922,
#       1750656104,
#       1356324586,
#       1831246701,
#       1962485102,
#       1710097399,
#       1144203134],
#      'tin': {'type': 'ein', 'value': '05-0606728'}},
#     {'npi': [1427030642, 1205808755],
#      'tin': {'type': 'ein', 'value': '20-0497490'}},
#     {'npi': [1609857291], 'tin': {'type': 'ein', 'value': '20-0658774'}},
#     {'npi': [1205833761, 1043215114, 1033114228, 1750386942],
#      'tin': {'type': 'ein', 'value': '20-1202415'}},
#     {'npi': [1205808755], 'tin': {'type': 'ein', 'value': '20-2004614'}},
#     {'npi': [1821002205,
#       1093922882,
#       1457549891,
#       1366603748,
#       1114940509,
#       1700093598],
#      'tin': {'type': 'ein', 'value': '20-2208207'}},
#     {'npi': [1891142048,
#       1760432546,
#       1245495043,
#       1073992707,
#       1851527394,
#       1538164678,
#       1508861287,
#       1285899088,
#       1346421369,
#       1811931546,
#       1417952185,
#       1114108255],
#      'tin': {'type': 'ein', 'value': '20-2620779'}},
#     {'npi': [1821052424,
#       1457730186,
#       1235344011,
#       1588009104,
#       1982051223,
#       1740600345,
#       1861673881,
#       1932162971,
#       1255968301,
#       1063040046,
#       1588628275,
#       1497958581,
#       1508829623,
#       1104389436,
#       1619930047,
#       1881891786,
#       1265540561,
#       1437611217,
#       1154818136,
#       1336646629,
#       1396900197,
#       1952515942,
#       1255956074,
#       1952693996,
#       1083677173,
#       1316434806,
#       1023071479,
#       1457497851,
#       1902369788,
#       1801329149,
#       1275596926],
#      'tin': {'type': 'ein', 'value': '20-2640268'}},
#     {'npi': [1205808755], 'tin': {'type': 'ein', 'value': '20-3489996'}},
#     {'npi': [1205833761, 1043215114, 1033114228, 1750386942],
#      'tin': {'type': 'ein', 'value': '20-3669979'}},
#     {'npi': [1437200037,
#       1205053352,
#       1851376073,
#       1275567182,
#       1184769424,
#       1477538163,
#       1659593655,
#       1235137688,
#       1700291903],
#      'tin': {'type': 'ein', 'value': '22-3940002'}},
#     {'npi': [1295741866, 1609857291],
#      'tin': {'type': 'ein', 'value': '26-3586636'}},
#     {'npi': [1205833761, 1043215114, 1033114228, 1750386942],
#      'tin': {'type': 'ein', 'value': '26-3957351'}},
#     {'npi': [1730154568,
#       1790985133,
#       1043746514,
#       1396815700,
#       1063634293,
#       1467606012],
#      'tin': {'type': 'ein', 'value': '27-0952681'}},
#     {'npi': [1144223645, 1073824439],
#      'tin': {'type': 'ein', 'value': '36-5120213'}},
#     {'npi': [1073584132,
#       1033371596,
#       1417975186,
#       1306003579,
#       1225215486,
#       1124325535],
#      'tin': {'type': 'ein', 'value': '47-1579306'}},
#     {'npi': [1205808755], 'tin': {'type': 'ein', 'value': '47-2248732'}},
#     {'npi': [1205808755], 'tin': {'type': 'ein', 'value': '47-3296778'}},
#     {'npi': [1609339266,
#       1821052424,
#       1457730186,
#       1235344011,
#       1588009104,
#       1982051223,
#       1740600345,
#       1801358106,
#       1861673881,
#       1932162971,
#       1598109597,
#       1326213919,
#       1295294114,
#       1255968301,
#       1063040046,
#       1679036974,
#       1588628275,
#       1497958581,
#       1508829623,
#       1104389436,
#       1619930047,
#       1881891786,
#       1497718860,
#       1265540561,
#       1437611217,
#       1497377873,
#       1437324118,
#       1154818136,
#       1679536098,
#       1336646629,
#       1396900197,
#       1952515942,
#       1255956074,
#       1972723179,
#       1952693996,
#       1083677173,
#       1316434806,
#       1023071479,
#       1457497851,
#       1902369788,
#       1275596926],
#      'tin': {'type': 'ein', 'value': '47-4262724'}},
#     {'npi': [1073518882,
#       1952367674,
#       1023468709,
#       1417941832,
#       1851404107,
#       1821228396,
#       1184690893,
#       1700995693,
#       1487151536,
#       1295729689,
#       1427317882,
#       1811903867,
#       1285016733,
#       1174539134],
#      'tin': {'type': 'ein', 'value': '59-2193856'}},
#     {'npi': [1194819441, 1619295441, 1710194071],
#      'tin': {'type': 'ein', 'value': '62-1664765'}},
#     {'npi': [1548289218,
#       1609835107,
#       1992023972,
#       1992778211,
#       1295708584,
#       1508075144,
#       1811417066,
#       1326380684,
#       1952817900,
#       1750354387,
#       1316500788,
#       1871728915,
#       1063823094,
#       1730566902,
#       1760616924,
#       1033177340,
#       1174889885,
#       1770789950],
#      'tin': {'type': 'ein', 'value': '63-0954295'}},
#     {'npi': [1669553764, 1417922238, 1164692711],
#      'tin': {'type': 'ein', 'value': '63-1225938'}},
#     {'npi': [1609339266,
#       1821052424,
#       1457730186,
#       1235344011,
#       1588009104,
#       1982051223,
#       1740600345,
#       1801358106,
#       1720252315,
#       1861673881,
#       1598109597,
#       1932162971,
#       1295294114,
#       1114486057,
#       1255968301,
#       1063040046,
#       1679036974,
#       1104821297,
#       1588628275,
#       1497958581,
#       1508829623,
#       1104389436,
#       1619930047,
#       1306804802,
#       1881891786,
#       1902369788,
#       1265540561,
#       1265495378,
#       1437611217,
#       1497377873,
#       1154818136,
#       1043421282,
#       1336646629,
#       1396900197,
#       1952515942,
#       1295792489,
#       1205213162,
#       1255956074,
#       1952693996,
#       1427030642,
#       1083677173,
#       1316434806,
#       1023071479,
#       1457497851,
#       1124115068,
#       1801329149,
#       1275596926],
#      'tin': {'type': 'ein', 'value': '63-1226975'}},
#     {'npi': [1821052424,
#       1457730186,
#       1235344011,
#       1588009104,
#       1982051223,
#       1740600345,
#       1861673881,
#       1932162971,
#       1679036974,
#       1588628275,
#       1497958581,
#       1508829623,
#       1104389436,
#       1619930047,
#       1497718860,
#       1265540561,
#       1437611217,
#       1154818136,
#       1336646629,
#       1952515942,
#       1972723179,
#       1952693996,
#       1083677173,
#       1316434806,
#       1023071479,
#       1457497851,
#       1902369788,
#       1801329149,
#       1275596926],
#      'tin': {'type': 'ein', 'value': '63-1245407'}},
#     {'npi': [1689085573,
#       1124521992,
#       1467915017,
#       1346690187,
#       1932595980,
#       1851374607,
#       1952367120,
#       1023091857,
#       1578744595,
#       1063776532,
#       1780648212,
#       1902086549,
#       1588839575,
#       1720252315,
#       1407072028,
#       1942283932,
#       1124089503,
#       1417930660,
#       1164618278,
#       1184087975,
#       1861491367,
#       1225473325,
#       1497761837,
#       1952384943,
#       1073960241,
#       1487637427,
#       1174506166,
#       1689794620,
#       1386164671,
#       1699162818,
#       1255314118,
#       1962683979,
#       1053526988,
#       1386951887,
#       1104270420,
#       1669505368,
#       1306870746,
#       1912980954,
#       1447239389,
#       1366429151,
#       1508848607,
#       1033192034,
#       1306829155,
#       1669553764,
#       1710947684,
#       1760659684,
#       1942397922,
#       1750656104,
#       1356324586,
#       1831246701,
#       1962485102,
#       1710097399,
#       1144203134],
#      'tin': {'type': 'ein', 'value': '63-1280228'}},
#     {'npi': [1609339266,
#       1821052424,
#       1457730186,
#       1235344011,
#       1588009104,
#       1982051223,
#       1740600345,
#       1861673881,
#       1720252315,
#       1932162971,
#       1255968301,
#       1063040046,
#       1679036974,
#       1104821297,
#       1588628275,
#       1497958581,
#       1508829623,
#       1104389436,
#       1619930047,
#       1881891786,
#       1902369788,
#       1265540561,
#       1437611217,
#       1154818136,
#       1336646629,
#       1396900197,
#       1952515942,
#       1255956074,
#       1972723179,
#       1952693996,
#       1427030642,
#       1083677173,
#       1316434806,
#       1023071479,
#       1457497851,
#       1124115068,
#       1801329149,
#       1275596926],
#      'tin': {'type': 'ein', 'value': '81-0764948'}},
#     {'npi': [1609339266,
#       1821052424,
#       1457730186,
#       1235344011,
#       1588009104,
#       1982051223,
#       1740600345,
#       1861673881,
#       1932162971,
#       1598109597,
#       1326213919,
#       1255968301,
#       1063040046,
#       1679036974,
#       1588628275,
#       1497958581,
#       1508829623,
#       1104389436,
#       1619930047,
#       1881891786,
#       1497718860,
#       1265540561,
#       1437611217,
#       1497377873,
#       1437324118,
#       1154818136,
#       1679536098,
#       1336646629,
#       1396900197,
#       1952515942,
#       1255956074,
#       1972723179,
#       1952693996,
#       1083677173,
#       1316434806,
#       1023071479,
#       1457497851,
#       1902369788,
#       1801329149,
#       1275596926],
#      'tin': {'type': 'ein', 'value': '81-0774091'}},
#     {'npi': [1780674762, 1205808755, 1417989740],
#      'tin': {'type': 'ein', 'value': '81-4021291'}},
#     {'npi': [1427030642, 1205808755],
#      'tin': {'type': 'ein', 'value': '81-5350229'}},
#     {'npi': [1609339266,
#       1689019523,
#       1902845829,
#       1821052424,
#       1457730186,
#       1235344011,
#       1588009104,
#       1255305470,
#       1982051223,
#       1740600345,
#       1801358106,
#       1861673881,
#       1932162971,
#       1598109597,
#       1457497851,
#       1629031463,
#       1992700199,
#       1114486057,
#       1992905897,
#       1255968301,
#       1063040046,
#       1679036974,
#       1588628275,
#       1497958581,
#       1508829623,
#       1104389436,
#       1619930047,
#       1942423108,
#       1881891786,
#       1497718860,
#       1265540561,
#       1437611217,
#       1376922963,
#       1497377873,
#       1740227925,
#       1861446866,
#       1154818136,
#       1083647200,
#       1336646629,
#       1396900197,
#       1508861287,
#       1518385384,
#       1790074854,
#       1255956074,
#       1952515942,
#       1952693996,
#       1972723179,
#       1083677173,
#       1316434806,
#       1023071479,
#       1306003579,
#       1902369788,
#       1801329149,
#       1275596926],
#      'tin': {'type': 'ein', 'value': '81-5393966'}},
#     {'npi': [1922402981], 'tin': {'type': 'ein', 'value': '13-3757370'}},
#     {'npi': [1295741866], 'tin': {'type': 'ein', 'value': '20-0658774'}},
#     {'npi': [1437320256,
#       1760465413,
#       1427232966,
#       1083959142,
#       1942511688,
#       1003075433,
#       1972982569,
#       1992095707,
#       1699725457,
#       1134306616,
#       1902291321,
#       1366425019],
#      'tin': {'type': 'ein', 'value': '20-0870135'}},
#     {'npi': [1942254883,
#       1780678052,
#       1558311910,
#       1659637767,
#       1740337542,
#       1417488271,
#       1881659407,
#       1043261969,
#       1134191828,
#       1740403583,
#       1154428159],
#      'tin': {'type': 'ein', 'value': '20-3660940'}},
#     {'npi': [1497109888,
#       1215059746,
#       1912975590,
#       1497980536,
#       1427030642,
#       1831419191,
#       1588691224,
#       1992765945],
#      'tin': {'type': 'ein', 'value': '27-5501752'}},
#     {'npi': [1427030642, 1720252315],
#      'tin': {'type': 'ein', 'value': '33-1370250'}},
#     {'npi': [1700095346], 'tin': {'type': 'ein', 'value': '46-5436928'}},
#     {'npi': [1093710832, 1043261969, 1619972874, 1538164785],
#      'tin': {'type': 'ein', 'value': '47-3518989'}},
#     {'npi': [1114486057], 'tin': {'type': 'ein', 'value': '47-4262724'}},
#     {'npi': [1578538112,
#       1588873350,
#       1548799885,
#       1912974734,
#       1497133458,
#       1982701462,
#       1114380193,
#       1629462825,
#       1588906671,
#       1831132083,
#       1801238969,
#       1073760831,
#       1023228624,
#       1528229986,
#       1447694823,
#       1114381548,
#       1295047280,
#       1912974833,
#       1730672122],
#      'tin': {'type': 'ein', 'value': '47-5195311'}},
#     {'npi': [1659358091,
#       1407948052,
#       1619947413,
#       1417165465,
#       1528285210,
#       1437270691,
#       1376520742,
#       1841257136,
#       1841232691,
#       1952582835,
#       1578506556,
#       1497074876,
#       1265728190,
#       1376998468,
#       1902101702,
#       1134161995,
#       1952388050,
#       1699966044,
#       1619954153,
#       1902933229,
#       1528000379,
#       1063451391],
#      'tin': {'type': 'ein', 'value': '58-1155460'}},
#     {'npi': [1023065687,
#       1396785929,
#       1003863598,
#       1598714750,
#       1417998071,
#       1598706046],
#      'tin': {'type': 'ein', 'value': '63-0313602'}},
#     {'npi': [1043261969, 1619972874, 1770927287, 1538164785],
#      'tin': {'type': 'ein', 'value': '63-0587021'}},
#     {'npi': [1598706046,
#       1396785929,
#       1932593548,
#       1013234830,
#       1215101092,
#       1740245927,
#       1659312171,
#       1003863598,
#       1003868977,
#       1326089913,
#       1710195516,
#       1023065687,
#       1831130459,
#       1659328227,
#       1225079783,
#       1013989995,
#       1851343727,
#       1417998071,
#       1396954749,
#       1598714750],
#      'tin': {'type': 'ein', 'value': '63-0732734'}},
#     {'npi': [1255391587,
#       1134447204,
#       1407065063,
#       1639378540,
#       1003215153,
#       1356872915,
#       1437119765,
#       1295794006,
#       1700846037,
#       1841855038],
#      'tin': {'type': 'ein', 'value': '63-0740487'}},
#     {'npi': [1265495378, 1235344011, 1952693996, 1023071479],
#      'tin': {'type': 'ein', 'value': '63-0782200'}},
#     {'npi': [1750485249,
#       1598706046,
#       1396785929,
#       1013234830,
#       1821056789,
#       1740245927,
#       1659312171,
#       1003863598,
#       1437253044,
#       1326089913,
#       1710195516,
#       1790832582,
#       1023065687,
#       1831130459,
#       1659328227,
#       1225079783,
#       1679677298,
#       1417998071,
#       1598714750],
#      'tin': {'type': 'ein', 'value': '63-0917491'}},
#     {'npi': [1265476592, 1811350481, 1114925237],
#      'tin': {'type': 'ein', 'value': '63-0925859'}},
#     {'npi': [1609835107,
#       1992023972,
#       1992778211,
#       1295708584,
#       1508075144,
#       1811417066,
#       1326380684,
#       1952817900,
#       1750354387,
#       1871728915,
#       1063823094,
#       1730566902,
#       1760616924,
#       1033177340,
#       1174889885,
#       1770789950],
#      'tin': {'type': 'ein', 'value': '63-0954295'}},
#     {'npi': [1720135684,
#       1952367120,
#       1578744595,
#       1588839575,
#       1417930660,
#       1164618278,
#       1184087975,
#       1225473325,
#       1952384943,
#       1073960241,
#       1487637427,
#       1689794620,
#       1386164671,
#       1699162818,
#       1255314118,
#       1962683979,
#       1104270420,
#       1306870746,
#       1265499099,
#       1508848607,
#       1306829155,
#       1750656104,
#       1710097399],
#      'tin': {'type': 'ein', 'value': '63-1059888'}},
#     {'npi': [1659328227,
#       1225079783,
#       1740245927,
#       1396785929,
#       1417998071,
#       1659312171,
#       1013234830,
#       1003863598,
#       1598714750,
#       1023065687,
#       1326089913,
#       1831130459,
#       1710195516,
#       1598706046],
#      'tin': {'type': 'ein', 'value': '63-1136330'}},
#     {'npi': [1356370787,
#       1487097127,
#       1538169099,
#       1275533549,
#       1952301327,
#       1619295441,
#       1235139668,
#       1538169974],
#      'tin': {'type': 'ein', 'value': '63-1174582'}},
#     {'npi': [1720046600,
#       1154882314,
#       1871550350,
#       1194141333,
#       1710194071,
#       1023491230,
#       1013361823,
#       1407931298,
#       1669783973,
#       1073570214,
#       1609096486,
#       1720046766,
#       1194911537,
#       1508954801,
#       1780636977,
#       1457618357,
#       1265843643,
#       1114016060,
#       1083692479,
#       1316089535,
#       1710307137,
#       1588622658,
#       1053472712,
#       1518924232,
#       1417114570,
#       1043742547,
#       1346338647,
#       1477556074,
#       1528156528,
#       1215132022,
#       1538169974,
#       1679521785,
#       1558364158],
#      'tin': {'type': 'ein', 'value': '63-1187140'}},
#     {'npi': [1699162818,
#       1306829155,
#       1942397922,
#       1962683979,
#       1225473325,
#       1689794620,
#       1851374607,
#       1952367120,
#       1952384943,
#       1962485102,
#       1487637427,
#       1710097399,
#       1588839575,
#       1407072028,
#       1144203134],
#      'tin': {'type': 'ein', 'value': '63-1207586'}},
#     {'npi': [1225082696, 1730133067, 1053409060, 1346350261],
#      'tin': {'type': 'ein', 'value': '63-1215126'}},
#     {'npi': [1609339266,
#       1821052424,
#       1457730186,
#       1235344011,
#       1588009104,
#       1982051223,
#       1740600345,
#       1861673881,
#       1720252315,
#       1932162971,
#       1063040046,
#       1104821297,
#       1588628275,
#       1497958581,
#       1104389436,
#       1619930047,
#       1306804802,
#       1881891786,
#       1902369788,
#       1265540561,
#       1265495378,
#       1437611217,
#       1497377873,
#       1154818136,
#       1336646629,
#       1396900197,
#       1952515942,
#       1205213162,
#       1255956074,
#       1952693996,
#       1427030642,
#       1083677173,
#       1316434806,
#       1023071479,
#       1457497851,
#       1124115068,
#       1801329149,
#       1275596926],
#      'tin': {'type': 'ein', 'value': '63-1226975'}},
#     {'npi': [1477506871], 'tin': {'type': 'ein', 'value': '63-1245407'}},
#     {'npi': [1033592704,
#       1134347271,
#       1518345362,
#       1275693590,
#       1588839575,
#       1972917276,
#       1184642977,
#       1184087975,
#       1073707816,
#       1730127531,
#       1225473325,
#       1396205357,
#       1326231473,
#       1336342328,
#       1376598458,
#       1689794620,
#       1699162818,
#       1053817668,
#       1780856013,
#       1669425104,
#       1477554517,
#       1720377435,
#       1801840731,
#       1003435744,
#       1952437345,
#       1306829155,
#       1285962852,
#       1538692967,
#       1568037489,
#       1831145978,
#       1801885819,
#       1235170812,
#       1760827901],
#      'tin': {'type': 'ein', 'value': '63-1262177'}},
#     {'npi': [1104917764,
#       1528055142,
#       1760478440,
#       1477714889,
#       1528528585,
#       1235344011,
#       1578772331,
#       1275533549,
#       1821052424,
#       1275825135,
#       1912433392,
#       1417166166,
#       1093203895,
#       1780642710,
#       1588041883],
#      'tin': {'type': 'ein', 'value': '63-1283588'}},
#     {'npi': [1750475331,
#       1558311910,
#       1659637767,
#       1093918088,
#       1740337542,
#       1942820808,
#       1417488271,
#       1881659407,
#       1154393841,
#       1134191828,
#       1679545438],
#      'tin': {'type': 'ein', 'value': '72-1376223'}},
#     {'npi': [1710481783], 'tin': {'type': 'ein', 'value': '81-5393966'}},
#     {'npi': [1932162971,
#       1336646629,
#       1043898760,
#       1821052424,
#       1457730186,
#       1235344011,
#       1821056680,
#       1982051223,
#       1023071479,
#       1861673881,
#       1457497851,
#       1619930047],
#      'tin': {'type': 'ein', 'value': '84-4617903'}},
#     {'npi': [1699162818, 1710947684, 1053526988, 1689794620, 1386164671],
#      'tin': {'type': 'ein', 'value': '86-1147392'}},
#     {'npi': [1205808755], 'tin': {'type': 'ein', 'value': '88-1035062'}},
#     {'npi': [1205808755], 'tin': {'type': 'ein', 'value': '88-1047863'}},
#     {'npi': [1932162971,
#       1336646629,
#       1952515942,
#       1821052424,
#       1457730186,
#       1235344011,
#       1881891786,
#       1720086861,
#       1982051223,
#       1811350481,
#       1083677173,
#       1023071479,
#       1861673881,
#       1457497851,
#       1619930047],
#      'tin': {'type': 'ein', 'value': '92-2164113'}},
#     {'npi': [1518212026], 'tin': {'type': 'ein', 'value': '92-3966599'}},
#     {'npi': [1205808755], 'tin': {'type': 'ein', 'value': '99-0932466'}},
#     {'npi': [1205808755], 'tin': {'type': 'ein', 'value': '99-1116534'}},
#     {'npi': [1205808755], 'tin': {'type': 'ein', 'value': '99-1410742'}},
#     {'npi': [1780674762, 1205808755],
#      'tin': {'type': 'ein', 'value': '99-3186239'}},
#     {'npi': [1699162818,
#       1942397922,
#       1184087975,
#       1124521992,
#       1750656104,
#       1356324586,
#       1346690187,
#       1962683979,
#       1225473325,
#       1073960241,
#       1487637427,
#       1588839575,
#       1306870746,
#       1689794620,
#       1366429151],
#      'tin': {'type': 'ein', 'value': '26-4626109'}},
#     {'npi': [1881875896], 'tin': {'type': 'ein', 'value': '27-2458311'}},
#     {'npi': [1639630692,
#       1659799237,
#       1447783717,
#       1598128902,
#       1801010921,
#       1962679241,
#       1952966483,
#       1831207893],
#      'tin': {'type': 'ein', 'value': '63-0576885'}},
#     {'npi': [1982040580,
#       1144587270,
#       1558866186,
#       1558405902,
#       1083666705,
#       1912043795,
#       1699765271,
#       1861831067,
#       1922469147,
#       1689960478,
#       1285681957,
#       1871869990,
#       1316334634,
#       1477593663,
#       1659310787,
#       1508806597,
#       1942253893,
#       1053524686,
#       1871907022,
#       1588870224,
#       1669567954,
#       1164478178,
#       1457889891,
#       1043266281,
#       1164462321,
#       1124079603,
#       1881743607,
#       1831142264],
#      'tin': {'type': 'ein', 'value': '63-0889615'}},
#     {'npi': [1104037027,
#       1326206632,
#       1982789335,
#       1871678284,
#       1497966287,
#       1598928079,
#       1013129105,
#       1487790481,
#       1649355827,
#       1033370390,
#       1740236694,
#       1225355514,
#       1003932955],
#      'tin': {'type': 'ein', 'value': '63-1119002'}},
#     {'npi': [1396900197, 1902369788, 1154818136, 1457497851, 1104389436],
#      'tin': {'type': 'ein', 'value': '63-1245407'}},
#     {'npi': [1326041203, 1073824439],
#      'tin': {'type': 'ein', 'value': '76-0844725'}},
#     {'npi': [1396900197,
#       1255956074,
#       1457730186,
#       1497718860,
#       1497958581,
#       1104389436],
#      'tin': {'type': 'ein', 'value': '20-1135962'}},
# ...
#     {'npi': [1265493134], 'tin': {'type': 'ein', 'value': '63-1159822'}},
#     {'npi': [1780665703], 'tin': {'type': 'ein', 'value': '63-1165851'}},
#     {'npi': [1780071597], 'tin': {'type': 'ein', 'value': '63-1167962'}},
#     {'npi': [1376681676], 'tin': {'type': 'ein', 'value': '63-1176388'}},
#     {'npi': [1689257602,
#       1568430056,
#       1801829643,
#       1710118898,
#       1720098809,
#       1558321786],
#      'tin': {'type': 'ein', 'value': '63-1178135'}},
#     {'npi': [1871593566], 'tin': {'type': 'ein', 'value': '63-1183068'}},
#     {'npi': [1740209048], 'tin': {'type': 'ein', 'value': '63-1185055'}},
#     {'npi': [1073018065], 'tin': {'type': 'ein', 'value': '63-1185612'}},
#     {'npi': [1538232574], 'tin': {'type': 'ein', 'value': '63-1189798'}},
#     {'npi': [1568924900], 'tin': {'type': 'ein', 'value': '63-1212066'}},
#     {'npi': [1396813002, 1225106933],
#      'tin': {'type': 'ein', 'value': '63-1214436'}},
#     {'npi': [1093855371], 'tin': {'type': 'ein', 'value': '63-1216354'}},
#     {'npi': [1588634679], 'tin': {'type': 'ein', 'value': '63-1221672'}},
#     {'npi': [1669454351], 'tin': {'type': 'ein', 'value': '63-1224395'}},
#     {'npi': [1952326704], 'tin': {'type': 'ein', 'value': '63-1225044'}},
#     {'npi': [1104821099], 'tin': {'type': 'ein', 'value': '63-1225904'}},
#     {'npi': [1356978563], 'tin': {'type': 'ein', 'value': '63-1229025'}},
#     {'npi': [1528021474], 'tin': {'type': 'ein', 'value': '63-1229714'}},
#     {'npi': [1346212362], 'tin': {'type': 'ein', 'value': '63-1232758'}},
#     {'npi': [1487708145], 'tin': {'type': 'ein', 'value': '63-1242852'}},
#     {'npi': [1588670475], 'tin': {'type': 'ein', 'value': '63-1244183'}},
#     {'npi': [1528011079,
#       1831161611,
#       1528166832,
#       1992891345,
#       1891777298,
#       1558348219,
#       1467514687],
#      'tin': {'type': 'ein', 'value': '63-1245407'}},
#     {'npi': [1063831352], 'tin': {'type': 'ein', 'value': '63-1245447'}},
#     {'npi': [1063444644], 'tin': {'type': 'ein', 'value': '63-1245880'}},
#     {'npi': [1093829640, 1982101846, 1801272638, 1548599798],
#      'tin': {'type': 'ein', 'value': '63-1246103'}},
#     {'npi': [1649247545], 'tin': {'type': 'ein', 'value': '63-1246246'}},
#     {'npi': [1457094682], 'tin': {'type': 'ein', 'value': '63-1250458'}},
#     {'npi': [1366596405], 'tin': {'type': 'ein', 'value': '63-1250938'}},
#     {'npi': [1194832204], 'tin': {'type': 'ein', 'value': '63-1252822'}},
#     {'npi': [1760464820], 'tin': {'type': 'ein', 'value': '63-1256129'}},
#     {'npi': [1871594176,
#       1821319971,
#       1306880364,
#       1508971953,
#       1730249525,
#       1225139959],
#      'tin': {'type': 'ein', 'value': '63-1262716'}},
#     {'npi': [1619998028], 'tin': {'type': 'ein', 'value': '63-1264086'}},
#     {'npi': [1710629522], 'tin': {'type': 'ein', 'value': '63-1266801'}},
#     {'npi': [1578524369], 'tin': {'type': 'ein', 'value': '63-1271423'}},
#     {'npi': [1538122825], 'tin': {'type': 'ein', 'value': '63-1274212'}},
#     {'npi': [1225077795, 1134625452],
#      'tin': {'type': 'ein', 'value': '63-1276483'}},
#     {'npi': [1922080084], 'tin': {'type': 'ein', 'value': '63-1276621'}},
#     {'npi': [1245233832, 1477050680, 1790717858],
#      'tin': {'type': 'ein', 'value': '63-1282722'}},
#     {'npi': [1861420994], 'tin': {'type': 'ein', 'value': '63-1285719'}},
#     {'npi': [1992778005, 1376516526],
#      'tin': {'type': 'ein', 'value': '63-6000288'}},
#     {'npi': [1194770222, 1083605190],
#      'tin': {'type': 'ein', 'value': '63-6000526'}},
#     {'npi': [1316023708], 'tin': {'type': 'ein', 'value': '63-6001097'}},
#     {'npi': [1437488681], 'tin': {'type': 'ein', 'value': '63-6001138'}},
#     {'npi': [1871693408, 1902354277, 1629084694],
#      'tin': {'type': 'ein', 'value': '63-6001641'}},
#     {'npi': [1356978563, 1972531127, 1548336951, 1275775165, 1528268703],
#      'tin': {'type': 'ein', 'value': '63-6001820'}},
#     {'npi': [1629055330, 1174584171, 1497920276, 1679523898],
#      'tin': {'type': 'ein', 'value': '63-6001875'}},
#     {'npi': [1730293366], 'tin': {'type': 'ein', 'value': '63-6004474'}},
#     {'npi': [1033209473,
#       1518546498,
#       1528049863,
#       1548755051,
#       1609385293,
#       1972562767,
#       1891015574,
#       1487391033,
#       1407586779],
#      'tin': {'type': 'ein', 'value': '63-6004476'}},
#     {'npi': [1619993649], 'tin': {'type': 'ein', 'value': '63-6004960'}},
#     {'npi': [1528353992, 1104856905, 1093815722],
#      'tin': {'type': 'ein', 'value': '63-6005283'}},
#     {'npi': [1912979592], 'tin': {'type': 'ein', 'value': '64-0561811'}},
#     {'npi': [1730143009], 'tin': {'type': 'ein', 'value': '64-0645887'}},
#     {'npi': [1609871607], 'tin': {'type': 'ein', 'value': '64-0655662'}},
#     {'npi': [1841273646], 'tin': {'type': 'ein', 'value': '64-0655993'}},
#     {'npi': [1174150783], 'tin': {'type': 'ein', 'value': '64-0801795'}},
#     {'npi': [1134350465], 'tin': {'type': 'ein', 'value': '64-0834917'}},
#     {'npi': [1003870494], 'tin': {'type': 'ein', 'value': '64-0926753'}},
#     {'npi': [1215928122, 1538553607],
#      'tin': {'type': 'ein', 'value': '64-6001528'}},
#     {'npi': [1699967612], 'tin': {'type': 'ein', 'value': '68-0654576'}},
#     {'npi': [1679654917], 'tin': {'type': 'ein', 'value': '72-1342111'}},
#     {'npi': [1760444608], 'tin': {'type': 'ein', 'value': '72-1347315'}},
#     {'npi': [1427157254], 'tin': {'type': 'ein', 'value': '72-1353451'}},
#     {'npi': [1043746845], 'tin': {'type': 'ein', 'value': '72-1358526'}},
#     {'npi': [1376833319], 'tin': {'type': 'ein', 'value': '72-1366527'}},
#     {'npi': [1467434373], 'tin': {'type': 'ein', 'value': '72-1374881'}},
#     {'npi': [1558310672], 'tin': {'type': 'ein', 'value': '72-1388298'}},
#     {'npi': [1649377664], 'tin': {'type': 'ein', 'value': '72-1391850'}},
#     {'npi': [1396806121, 1447311295],
#      'tin': {'type': 'ein', 'value': '72-1393103'}},
#     {'npi': [1619920451, 1467468355, 1568924900, 1437324613],
#      'tin': {'type': 'ein', 'value': '72-1425772'}},
#     {'npi': [1194761858, 1164458253],
#      'tin': {'type': 'ein', 'value': '72-1589022'}},
#     {'npi': [1104069228,
#       1265722540,
#       1104849843,
#       1316926389,
#       1982970232,
#       1679505465,
#       1265543482,
#       1871117341,
#       1770644031],
#      'tin': {'type': 'ein', 'value': '72-1608375'}},
#     {'npi': [1467429480, 1841264231],
#      'tin': {'type': 'ein', 'value': '80-0278187'}},
#     {'npi': [1285204123], 'tin': {'type': 'ein', 'value': '80-0746903'}},
#     {'npi': [1740281880], 'tin': {'type': 'ein', 'value': '81-2146883'}},
#     {'npi': [1639186596], 'tin': {'type': 'ein', 'value': '81-2367845'}},
#     {'npi': [1679197149], 'tin': {'type': 'ein', 'value': '81-3116506'}},
#     {'npi': [1063831352, 1033209473, 1124042619],
#      'tin': {'type': 'ein', 'value': '81-3158598'}},
#     {'npi': [1992810345], 'tin': {'type': 'ein', 'value': '81-3879922'}},
#     {'npi': [1164635926], 'tin': {'type': 'ein', 'value': '81-4205358'}},
#     {'npi': [1669793220], 'tin': {'type': 'ein', 'value': '81-4314431'}},
#     {'npi': [1346352317], 'tin': {'type': 'ein', 'value': '81-4629342'}},
#     {'npi': [1255950994], 'tin': {'type': 'ein', 'value': '81-5090337'}},
#     {'npi': [1306848494], 'tin': {'type': 'ein', 'value': '81-5167175'}},
#     {'npi': [1922387299], 'tin': {'type': 'ein', 'value': '82-0713273'}},
#     {'npi': [1922442755], 'tin': {'type': 'ein', 'value': '82-0935311'}},
#     {'npi': [1578524369], 'tin': {'type': 'ein', 'value': '82-1095929'}},
#     {'npi': [1184663296, 1295780161, 1184691859, 1770697500],
#      'tin': {'type': 'ein', 'value': '82-1388539'}},
#     {'npi': [1316040413], 'tin': {'type': 'ein', 'value': '82-1581847'}},
#     {'npi': [1134336886, 1396955381, 1134140734],
#      'tin': {'type': 'ein', 'value': '82-1897606'}},
#     {'npi': [1265533855], 'tin': {'type': 'ein', 'value': '82-1993081'}},
#     {'npi': [1346597804], 'tin': {'type': 'ein', 'value': '82-2029242'}},
#     {'npi': [1598831422], 'tin': {'type': 'ein', 'value': '82-2612399'}},
#     {'npi': [1275952517], 'tin': {'type': 'ein', 'value': '82-2650856'}},
#     {'npi': [1770987943], 'tin': {'type': 'ein', 'value': '82-2999869'}},
#     {'npi': [1609284751], 'tin': {'type': 'ein', 'value': '82-3282645'}},
#     {'npi': [1679568752], 'tin': {'type': 'ein', 'value': '82-3581907'}},
#     {'npi': [1881789063], 'tin': {'type': 'ein', 'value': '82-4810974'}},
#     {'npi': [1346597804], 'tin': {'type': 'ein', 'value': '82-5100190'}},
#     {'npi': [1821067067], 'tin': {'type': 'ein', 'value': '82-5384632'}},
#     {'npi': [1043329808], 'tin': {'type': 'ein', 'value': '83-0759273'}},
#     {'npi': [1306848494], 'tin': {'type': 'ein', 'value': '83-1261308'}},
#     {'npi': [1417390543], 'tin': {'type': 'ein', 'value': '83-1442487'}},
#     {'npi': [1982101846], 'tin': {'type': 'ein', 'value': '83-1651180'}},
#     {'npi': [1528083763], 'tin': {'type': 'ein', 'value': '83-2071497'}},
#     {'npi': [1821006628], 'tin': {'type': 'ein', 'value': '83-2122464'}},
#     {'npi': [1750532263,
#       1639386733,
#       1053501049,
#       1669434395,
#       1255693149,
#       1427377209],
#      'tin': {'type': 'ein', 'value': '83-4257679'}},
#     {'npi': [1013964261], 'tin': {'type': 'ein', 'value': '83-4272029'}},
#     {'npi': [1396705554, 1811984149],
#      'tin': {'type': 'ein', 'value': '83-4448194'}},
#     {'npi': [1922387299, 1568728814],
#      'tin': {'type': 'ein', 'value': '84-1809167'}},
#     {'npi': [1265428031], 'tin': {'type': 'ein', 'value': '84-2477019'}},
#     {'npi': [1518953900], 'tin': {'type': 'ein', 'value': '84-2671215'}},
#     {'npi': [1952303711], 'tin': {'type': 'ein', 'value': '84-3065639'}},
#     {'npi': [1922387299], 'tin': {'type': 'ein', 'value': '84-3223193'}},
#     {'npi': [1659457794], 'tin': {'type': 'ein', 'value': '84-3871966'}},
#     {'npi': [1033796685], 'tin': {'type': 'ein', 'value': '84-3919277'}},
#     {'npi': [1013085679], 'tin': {'type': 'ein', 'value': '84-4403995'}},
#     {'npi': [1790711513], 'tin': {'type': 'ein', 'value': '84-4714209'}},
#     {'npi': [1780665703], 'tin': {'type': 'ein', 'value': '84-4785596'}},
#     {'npi': [1467676676], 'tin': {'type': 'ein', 'value': '85-0674776'}},
#     {'npi': [1710972385], 'tin': {'type': 'ein', 'value': '85-1102035'}},
#     {'npi': [1124059399], 'tin': {'type': 'ein', 'value': '85-1256417'}},
#     {'npi': [1104893809], 'tin': {'type': 'ein', 'value': '85-1597059'}},
#     {'npi': [1083643142], 'tin': {'type': 'ein', 'value': '85-2312653'}},
#     {'npi': [1588612980], 'tin': {'type': 'ein', 'value': '85-2506513'}},
#     {'npi': [1194885681, 1891015574],
#      'tin': {'type': 'ein', 'value': '85-3168616'}},
#     {'npi': [1285029371], 'tin': {'type': 'ein', 'value': '85-3434682'}},
#     {'npi': [1568635845], 'tin': {'type': 'ein', 'value': '85-3499265'}},
#     {'npi': [1386388569], 'tin': {'type': 'ein', 'value': '85-3637980'}},
#     {'npi': [1376718080], 'tin': {'type': 'ein', 'value': '85-4024115'}},
#     {'npi': [1124214770], 'tin': {'type': 'ein', 'value': '86-1592901'}},
#     {'npi': [1568728814], 'tin': {'type': 'ein', 'value': '86-2117102'}},
#     {'npi': [1811383128], 'tin': {'type': 'ein', 'value': '86-2625437'}},
#     {'npi': [1891254876, 1578182358, 1013476951],
#      'tin': {'type': 'ein', 'value': '86-3208536'}},
#     {'npi': [1083681589], 'tin': {'type': 'ein', 'value': '86-3500400'}},
#     {'npi': [1982625869], 'tin': {'type': 'ein', 'value': '86-3902072'}},
#     {'npi': [1215298849], 'tin': {'type': 'ein', 'value': '87-0878032'}},
#     {'npi': [1033504428], 'tin': {'type': 'ein', 'value': '87-0970152'}},
#     {'npi': [1770591950], 'tin': {'type': 'ein', 'value': '87-2053094'}},
#     {'npi': [1194770461], 'tin': {'type': 'ein', 'value': '87-2183228'}},
#     {'npi': [1992786636], 'tin': {'type': 'ein', 'value': '87-2353515'}},
#     {'npi': [1720037450], 'tin': {'type': 'ein', 'value': '87-3224337'}},
#     {'npi': [1770655813, 1205154127, 1023671120, 1124581137, 1427141241],
#      'tin': {'type': 'ein', 'value': '87-3773130'}},
#     {'npi': [1083687990], 'tin': {'type': 'ein', 'value': '87-4233167'}},
#     {'npi': [1871080986], 'tin': {'type': 'ein', 'value': '88-1467023'}},
#     {'npi': [1528490513], 'tin': {'type': 'ein', 'value': '88-1991358'}},
#     {'npi': [1215298849], 'tin': {'type': 'ein', 'value': '88-2109616'}},
#     {'npi': [1023086675, 1396126165, 1639147119],
#      'tin': {'type': 'ein', 'value': '88-2472117'}},
#     {'npi': [1245560796], 'tin': {'type': 'ein', 'value': '88-2966445'}},
#     {'npi': [1992741284], 'tin': {'type': 'ein', 'value': '88-3097275'}},
#     {'npi': [1295779353], 'tin': {'type': 'ein', 'value': '88-3161807'}},
#     {'npi': [1649833906], 'tin': {'type': 'ein', 'value': '88-4108804'}},
#     {'npi': [1093814980], 'tin': {'type': 'ein', 'value': '90-0776613'}},
#     {'npi': [1902197825], 'tin': {'type': 'ein', 'value': '92-0520226'}},
#     {'npi': [1609881333], 'tin': {'type': 'ein', 'value': '92-0524329'}},
#     {'npi': [1922387299], 'tin': {'type': 'ein', 'value': '92-0962846'}},
#     {'npi': [1316309479], 'tin': {'type': 'ein', 'value': '92-1184350'}},
#     {'npi': [1659531200, 1083681589],
#      'tin': {'type': 'ein', 'value': '92-1582601'}},
#     {'npi': [1295964682], 'tin': {'type': 'ein', 'value': '92-1813169'}},
#     {'npi': [1245233832, 1477050680],
#      'tin': {'type': 'ein', 'value': '92-1894066'}},
#     {'npi': [1659531200], 'tin': {'type': 'ein', 'value': '92-3428231'}},
#     {'npi': [1649452301], 'tin': {'type': 'ein', 'value': '92-3463892'}},
#     {'npi': [1750354544, 1609002500],
#      'tin': {'type': 'ein', 'value': '92-3841011'}},
#     {'npi': [1902934359], 'tin': {'type': 'ein', 'value': '92-3866799'}},
#     {'npi': [1831414358], 'tin': {'type': 'ein', 'value': '92-3984495'}},
#     {'npi': [1184663296, 1760748172, 1346256260, 1750532263],
#      'tin': {'type': 'ein', 'value': '93-1371454'}},
#     {'npi': [1629692769, 1477172211],
#      'tin': {'type': 'ein', 'value': '93-1840394'}},
#     {'npi': [1518953900], 'tin': {'type': 'ein', 'value': '93-2471652'}},
#     {'npi': [1154749554], 'tin': {'type': 'ein', 'value': '93-2719394'}},
#     {'npi': [1518924547], 'tin': {'type': 'ein', 'value': '93-3156362'}},
#     {'npi': [1588750566], 'tin': {'type': 'ein', 'value': '93-3367284'}},
#     {'npi': [1164635926], 'tin': {'type': 'ein', 'value': '93-3747554'}},
#     {'npi': [1720051584, 1396157194, 1811916620],
#      'tin': {'type': 'ein', 'value': '93-3833435'}},
#     {'npi': [1477872554], 'tin': {'type': 'ein', 'value': '93-4102172'}},
#     {'npi': [1932415775], 'tin': {'type': 'ein', 'value': '93-4961791'}},
#     {'npi': [1831414358], 'tin': {'type': 'ein', 'value': '99-0530133'}},
#     {'npi': [1073568812], 'tin': {'type': 'ein', 'value': '99-0697219'}},
#     {'npi': [1568488708], 'tin': {'type': 'ein', 'value': '99-0818031'}},
#     {'npi': [1992786636, 1083111579, 1245560796, 1285963421],
#      'tin': {'type': 'ein', 'value': '99-0835906'}},
#     {'npi': [1679654917], 'tin': {'type': 'ein', 'value': '99-1475589'}},
#     {'npi': [1912955147, 1073778023],
#      'tin': {'type': 'ein', 'value': '99-2666674'}},
#     {'npi': [1619187663], 'tin': {'type': 'ein', 'value': '99-2781985'}},
#     {'npi': [1629692769, 1346597804],
#      'tin': {'type': 'ein', 'value': '99-3291928'}},
#     {'npi': [1932156577, 1679654917],
#      'tin': {'type': 'ein', 'value': '99-3299215'}},
#     {'npi': [1598831422], 'tin': {'type': 'ein', 'value': '99-3347183'}},
#     {'npi': [1568662039], 'tin': {'type': 'ein', 'value': '99-3759638'}},
#     {'npi': [1568509198], 'tin': {'type': 'ein', 'value': '99-3911648'}},
#     {'npi': [1285193268], 'tin': {'type': 'ein', 'value': '99-4068580'}},
#     {'npi': [1578770152], 'tin': {'type': 'ein', 'value': '99-4470212'}},
#     {'npi': [1659513919], 'tin': {'type': 'ein', 'value': '99-4571990'}},
#     {'npi': [1225139959], 'tin': {'type': 'ein', 'value': '99-4827168'}},
#     {'npi': [1659531200, 1386388569],
#      'tin': {'type': 'ein', 'value': '99-4936877'}}],
#    'negotiated_prices': [{'negotiated_type': 'negotiated',
#      'negotiated_rate': 28.85,
#      'expiration_date': '9999-12-31',
#      'service_code': ['21', '22', '24', '31', '55', '93', '99'],
#      'billing_class': 'professional'}]}]}
